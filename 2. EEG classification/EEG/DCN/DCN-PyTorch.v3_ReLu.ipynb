# %%
import numpy as np 
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import dataloader as da

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 120

        # Layer 1
        self.conv1 = nn.Conv2d(1, 25, kernel_size = (1, 5))
        self.conv2 = nn.Conv2d(25, 50, kernel_size = (2, 1))
        self.batchnorm1 = nn.BatchNorm2d(50, eps = 1e-05, momentum=0.1)
        self.pooling1 = nn.MaxPool2d(kernel_size=(1, 2))
        
        # Layer 2
        self.conv3 = nn.Conv2d(50, 100, kernel_size = (1, 5))
        self.batchnorm2 = nn.BatchNorm2d(100, eps = 1e-05, momentum=0.1)
        self.pooling2 = nn.MaxPool2d(kernel_size=(1, 2))
        
        # Layer 3
        self.conv4 = nn.Conv2d(100, 200, kernel_size = (1, 5))
        self.batchnorm3 = nn.BatchNorm2d(200, eps = 1e-05, momentum=0.1)
        self.pooling3 = nn.MaxPool2d(kernel_size=(1, 2))        
        
        # Layer 4
        self.conv5 = nn.Conv2d(200, 400, kernel_size = (1, 5))        
        self.batchnorm4 = nn.BatchNorm2d(400, eps = 1e-05, momentum=0.1)
        self.pooling4 = nn.MaxPool2d(kernel_size=(1, 2))             
        
        # FC Layer
        # NOTE: This dimension will depend on the number of timestamps per sample in your data.
        # I have 120 timepoints. 
        self.fc1 = nn.Linear(in_features = 17200, out_features = 1, bias = True)
        
    def forward(self, x):

        # Layer 1
        x = self.conv1(x)
        x = self.conv2(x)        
        x = self.batchnorm1(x)
        x = F.relu(x)
        x = self.pooling1(x)
        x = F.dropout(x, 0.5)
        
        # Layer 2
        x = self.conv3(x)
        x = self.batchnorm2(x)
        x = F.relu(x)
        x = self.pooling2(x)
        x = F.dropout(x, 0.5)
        
        # Layer 3
        x = self.conv4(x)
        x = self.batchnorm3(x)
        x = F.relu(x)
        x = self.pooling3(x)      
        x = F.dropout(x, 0.5)
        
        # Layer 4
        x = self.conv5(x)
        x = self.batchnorm4(x)
        x = F.relu(x)
        x = self.pooling4(x)      
        x = F.dropout(x, 0.5)

        # FC Layer
        x = x.view(-1, 17200)
        x = self.fc1(x)
        x = F.sigmoid(x)

        return x

# %%
def evaluate(model, X, Y, params = ["acc"]):
    results = []
    batch_size = 64
    
    predicted = []
    
    for i in range(int(len(X)/batch_size)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = Variable(torch.from_numpy(X[s:e]).cuda(0))
        pred = model(inputs)
        
        predicted.append(pred.data.cpu().numpy())
        
        
    inputs = Variable(torch.from_numpy(X).cuda(0))
    predicted = model(inputs)
    
    predicted = predicted.data.cpu().numpy()
    
    for param in params:
        if param == 'acc':
            results.append(accuracy_score(Y, np.round(predicted)))
        if param == "auc":
            results.append(roc_auc_score(Y, predicted))
        if param == "recall":
            results.append(recall_score(Y, np.round(predicted)))
        if param == "precision":
            results.append(precision_score(Y, np.round(predicted)))
        if param == "fmeasure":
            precision = precision_score(Y, np.round(predicted))
            recall = recall_score(Y, np.round(predicted))
            results.append(2*precision*recall/ (precision+recall))
    return results

# %%
X_train, y_train, X_test, y_test = da.read_bci_data()
# Out:
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)

# %%
batch_size = 64
net = EEGNet().cuda(0)
criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())
train_output = []
test_output = []

for epoch in range(300):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    running_loss = 0.0
    for i in range(int(len(X_train)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_train[s:e]).float()
        labels = torch.FloatTensor(np.array([y_train[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        train_output += outputs.T.tolist()[0]

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.data
    
    for i in range(int(len(X_test)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_test[s:e]).float()
        labels = torch.FloatTensor(np.array([y_test[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        test_output += outputs.T.tolist()[0]


    train_accuracy = accuracy_score(np.array(y_train[0:960]), np.array(train_output).round())        
    train_output = []
    test_accuracy = accuracy_score(np.array(y_test[0:960]), np.array(test_output).round())    
    test_output = []
    
    # Validation accuracy
    params = ["acc", "auc", "fmeasure"]
    print(params) 
    print("Training Loss ", running_loss)
    print("train_accuracy ", train_accuracy*100, "%")
    print("test_accuracy ", test_accuracy*100, "%")   
#     print("Train - ", evaluate(net, X_train, y_train, params))
#     print("Validation - ", evaluate(net, X_val, y_val, params))
#     print("Test - ", evaluate(net, X_test, y_test, params))
# Out:
# Epoch  0
# /root/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(19.2639, device='cuda:0')
# train_accuracy  52.604166666666664 %
# test_accuracy  61.5625 %
#
# Epoch  1
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(10.7573, device='cuda:0')
# train_accuracy  65.625 %
# test_accuracy  61.77083333333333 %
#
# Epoch  2
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(10.7323, device='cuda:0')
# train_accuracy  67.39583333333333 %
# test_accuracy  70.41666666666667 %
#
# Epoch  3
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(9.0887, device='cuda:0')
# train_accuracy  72.91666666666666 %
# test_accuracy  69.89583333333333 %
#
# Epoch  4
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(9.2787, device='cuda:0')
# train_accuracy  71.5625 %
# test_accuracy  72.5 %
#
# Epoch  5
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.7727, device='cuda:0')
# train_accuracy  72.8125 %
# test_accuracy  68.02083333333333 %
#
# Epoch  6
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(9.3261, device='cuda:0')
# train_accuracy  71.45833333333333 %
# test_accuracy  64.89583333333333 %
#
# Epoch  7
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(14.2086, device='cuda:0')
# train_accuracy  66.14583333333334 %
# test_accuracy  54.479166666666664 %
#
# Epoch  8
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(24.9835, device='cuda:0')
# train_accuracy  65.10416666666666 %
# test_accuracy  52.39583333333333 %
#
# Epoch  9
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(30.5539, device='cuda:0')
# train_accuracy  64.89583333333333 %
# test_accuracy  65.83333333333333 %
#
# Epoch  10
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(17.7004, device='cuda:0')
# train_accuracy  71.66666666666667 %
# test_accuracy  65.41666666666667 %
#
# Epoch  11
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(13.8949, device='cuda:0')
# train_accuracy  70.83333333333334 %
# test_accuracy  61.458333333333336 %
#
# Epoch  12
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(15.7575, device='cuda:0')
# train_accuracy  69.375 %
# test_accuracy  70.10416666666667 %
#
# Epoch  13
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.9120, device='cuda:0')
# train_accuracy  72.39583333333334 %
# test_accuracy  62.18749999999999 %
#
# Epoch  14
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.7518, device='cuda:0')
# train_accuracy  75.9375 %
# test_accuracy  72.91666666666666 %
#
# Epoch  15
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.7311, device='cuda:0')
# train_accuracy  74.6875 %
# test_accuracy  65.10416666666666 %
#
# Epoch  16
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(9.0975, device='cuda:0')
# train_accuracy  74.89583333333333 %
# test_accuracy  73.02083333333333 %
#
# Epoch  17
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.1972, device='cuda:0')
# train_accuracy  77.39583333333333 %
# test_accuracy  73.22916666666667 %
#
# Epoch  18
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6257, device='cuda:0')
# train_accuracy  78.22916666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  19
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3703, device='cuda:0')
# train_accuracy  79.79166666666667 %
# test_accuracy  73.54166666666667 %
#
# Epoch  20
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2564, device='cuda:0')
# train_accuracy  80.10416666666667 %
# test_accuracy  73.33333333333333 %
#
# Epoch  21
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0683, device='cuda:0')
# train_accuracy  79.89583333333333 %
# test_accuracy  70.9375 %
#
# Epoch  22
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2882, device='cuda:0')
# train_accuracy  80.3125 %
# test_accuracy  73.64583333333333 %
#
# Epoch  23
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8144, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  73.85416666666667 %
#
# Epoch  24
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8120, device='cuda:0')
# train_accuracy  81.35416666666667 %
# test_accuracy  72.5 %
#
# Epoch  25
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9569, device='cuda:0')
# train_accuracy  79.47916666666667 %
# test_accuracy  70.625 %
#
# Epoch  26
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3281, device='cuda:0')
# train_accuracy  80.83333333333333 %
# test_accuracy  69.0625 %
#
# Epoch  27
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.4532, device='cuda:0')
# train_accuracy  80.41666666666667 %
# test_accuracy  70.10416666666667 %
#
# Epoch  28
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6115, device='cuda:0')
# train_accuracy  82.60416666666667 %
# test_accuracy  75.41666666666667 %
#
# Epoch  29
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2070, device='cuda:0')
# train_accuracy  79.89583333333333 %
# test_accuracy  69.375 %
#
# Epoch  30
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.3074, device='cuda:0')
# train_accuracy  77.8125 %
# test_accuracy  64.0625 %
#
# Epoch  31
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.6502, device='cuda:0')
# train_accuracy  77.60416666666666 %
# test_accuracy  68.95833333333333 %
#
# Epoch  32
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6142, device='cuda:0')
# train_accuracy  79.6875 %
# test_accuracy  71.45833333333333 %
#
# Epoch  33
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.1280, device='cuda:0')
# train_accuracy  76.04166666666666 %
# test_accuracy  61.66666666666667 %
#
# Epoch  34
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.6375, device='cuda:0')
# train_accuracy  78.22916666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  35
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.9643, device='cuda:0')
# train_accuracy  75.9375 %
# test_accuracy  65.20833333333333 %
#
# Epoch  36
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.9173, device='cuda:0')
# train_accuracy  78.33333333333333 %
# test_accuracy  74.375 %
#
# Epoch  37
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0061, device='cuda:0')
# train_accuracy  83.125 %
# test_accuracy  70.52083333333333 %
#
# Epoch  38
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8082, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  75.20833333333333 %
#
# Epoch  39
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2062, device='cuda:0')
# train_accuracy  84.89583333333334 %
# test_accuracy  71.875 %
#
# Epoch  40
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6222, device='cuda:0')
# train_accuracy  82.60416666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  41
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6456, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  71.5625 %
#
# Epoch  42
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1645, device='cuda:0')
# train_accuracy  83.95833333333333 %
# test_accuracy  72.39583333333334 %
#
# Epoch  43
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0365, device='cuda:0')
# train_accuracy  85.83333333333333 %
# test_accuracy  74.0625 %
#
# Epoch  44
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4321, device='cuda:0')
# train_accuracy  81.875 %
# test_accuracy  70.0 %
#
# Epoch  45
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4003, device='cuda:0')
# train_accuracy  83.22916666666667 %
# test_accuracy  74.27083333333333 %
#
# Epoch  46
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9644, device='cuda:0')
# train_accuracy  85.10416666666667 %
# test_accuracy  68.64583333333333 %
#
# Epoch  47
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1109, device='cuda:0')
# train_accuracy  81.875 %
# test_accuracy  73.54166666666667 %
#
# Epoch  48
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6862, device='cuda:0')
# train_accuracy  83.02083333333333 %
# test_accuracy  71.04166666666667 %
#
# Epoch  49
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5685, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  73.95833333333334 %
#
# Epoch  50
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7626, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  71.04166666666667 %
#
# Epoch  51
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8861, device='cuda:0')
# train_accuracy  86.66666666666667 %
# test_accuracy  74.16666666666667 %
#
# Epoch  52
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7500, device='cuda:0')
# train_accuracy  85.83333333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  53
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7927, device='cuda:0')
# train_accuracy  85.9375 %
# test_accuracy  73.54166666666667 %
#
# Epoch  54
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3505, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  74.47916666666666 %
#
# Epoch  55
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3967, device='cuda:0')
# train_accuracy  85.72916666666667 %
# test_accuracy  72.1875 %
#
# Epoch  56
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4773, device='cuda:0')
# train_accuracy  86.875 %
# test_accuracy  75.0 %
#
# Epoch  57
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4137, device='cuda:0')
# train_accuracy  86.5625 %
# test_accuracy  70.52083333333333 %
#
# Epoch  58
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9236, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  75.625 %
#
# Epoch  59
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4992, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  70.10416666666667 %
#
# Epoch  60
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0420, device='cuda:0')
# train_accuracy  84.79166666666667 %
# test_accuracy  74.89583333333333 %
#
# Epoch  61
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0146, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  70.3125 %
#
# Epoch  62
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8287, device='cuda:0')
# train_accuracy  86.5625 %
# test_accuracy  75.52083333333334 %
#
# Epoch  63
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3832, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  70.625 %
#
# Epoch  64
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3716, device='cuda:0')
# train_accuracy  87.39583333333333 %
# test_accuracy  73.95833333333334 %
#
# Epoch  65
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8733, device='cuda:0')
# train_accuracy  86.5625 %
# test_accuracy  71.77083333333333 %
#
# Epoch  66
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3161, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  73.4375 %
#
# Epoch  67
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4759, device='cuda:0')
# train_accuracy  86.97916666666666 %
# test_accuracy  73.85416666666667 %
#
# Epoch  68
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3911, device='cuda:0')
# train_accuracy  87.39583333333333 %
# test_accuracy  71.5625 %
#
# Epoch  69
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4057, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  75.41666666666667 %
#
# Epoch  70
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6226, device='cuda:0')
# train_accuracy  88.54166666666666 %
# test_accuracy  70.9375 %
#
# Epoch  71
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7263, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  76.45833333333333 %
#
# Epoch  72
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0986, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  73.54166666666667 %
#
# Epoch  73
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6934, device='cuda:0')
# train_accuracy  89.47916666666667 %
# test_accuracy  74.47916666666666 %
#
# Epoch  74
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6589, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  76.35416666666667 %
#
# Epoch  75
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5494, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  72.60416666666667 %
#
# Epoch  76
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0500, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  75.3125 %
#
# Epoch  77
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0921, device='cuda:0')
# train_accuracy  91.35416666666667 %
# test_accuracy  74.0625 %
#
# Epoch  78
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9409, device='cuda:0')
# train_accuracy  92.29166666666667 %
# test_accuracy  75.0 %
#
# Epoch  79
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.7704, device='cuda:0')
# train_accuracy  92.70833333333334 %
# test_accuracy  75.41666666666667 %
#
# Epoch  80
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5468, device='cuda:0')
# train_accuracy  93.125 %
# test_accuracy  75.10416666666667 %
#
# Epoch  81
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.6722, device='cuda:0')
# train_accuracy  92.5 %
# test_accuracy  75.3125 %
#
# Epoch  82
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.6620, device='cuda:0')
# train_accuracy  93.02083333333333 %
# test_accuracy  76.5625 %
#
# Epoch  83
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2211, device='cuda:0')
# train_accuracy  91.04166666666667 %
# test_accuracy  75.0 %
#
# Epoch  84
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.6964, device='cuda:0')
# train_accuracy  92.39583333333333 %
# test_accuracy  75.3125 %
#
# Epoch  85
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.6784, device='cuda:0')
# train_accuracy  92.91666666666667 %
# test_accuracy  77.08333333333334 %
#
# Epoch  86
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.6654, device='cuda:0')
# train_accuracy  92.29166666666667 %
# test_accuracy  75.625 %
#
# Epoch  87
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4682, device='cuda:0')
# train_accuracy  92.91666666666667 %
# test_accuracy  73.64583333333333 %
#
# Epoch  88
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2905, device='cuda:0')
# train_accuracy  93.85416666666667 %
# test_accuracy  77.39583333333333 %
#
# Epoch  89
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4574, device='cuda:0')
# train_accuracy  93.85416666666667 %
# test_accuracy  75.3125 %
#
# Epoch  90
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2963, device='cuda:0')
# train_accuracy  93.54166666666667 %
# test_accuracy  75.83333333333333 %
#
# Epoch  91
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9242, device='cuda:0')
# train_accuracy  94.79166666666666 %
# test_accuracy  75.9375 %
#
# Epoch  92
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2234, device='cuda:0')
# train_accuracy  94.16666666666667 %
# test_accuracy  74.89583333333333 %
#
# Epoch  93
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9945, device='cuda:0')
# train_accuracy  95.52083333333333 %
# test_accuracy  77.60416666666666 %
#
# Epoch  94
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9456, device='cuda:0')
# train_accuracy  94.89583333333333 %
# test_accuracy  75.3125 %
#
# Epoch  95
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2526, device='cuda:0')
# train_accuracy  93.85416666666667 %
# test_accuracy  75.625 %
#
# Epoch  96
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0123, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  74.16666666666667 %
#
# Epoch  97
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1479, device='cuda:0')
# train_accuracy  94.58333333333333 %
# test_accuracy  74.375 %
#
# Epoch  98
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1655, device='cuda:0')
# train_accuracy  94.47916666666667 %
# test_accuracy  75.9375 %
#
# Epoch  99
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.7358, device='cuda:0')
# train_accuracy  92.70833333333334 %
# test_accuracy  74.375 %
#
# Epoch  100
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2843, device='cuda:0')
# train_accuracy  93.33333333333333 %
# test_accuracy  75.3125 %
#
# Epoch  101
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.3355, device='cuda:0')
# train_accuracy  93.4375 %
# test_accuracy  71.04166666666667 %
#
# Epoch  102
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0910, device='cuda:0')
# train_accuracy  90.625 %
# test_accuracy  75.72916666666667 %
#
# Epoch  103
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3693, device='cuda:0')
# train_accuracy  91.04166666666667 %
# test_accuracy  73.4375 %
#
# Epoch  104
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9085, device='cuda:0')
# train_accuracy  90.625 %
# test_accuracy  73.75 %
#
# Epoch  105
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.8321, device='cuda:0')
# train_accuracy  91.97916666666667 %
# test_accuracy  70.0 %
#
# Epoch  106
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4949, device='cuda:0')
# train_accuracy  89.79166666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  107
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0665, device='cuda:0')
# train_accuracy  92.70833333333334 %
# test_accuracy  73.4375 %
#
# Epoch  108
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5425, device='cuda:0')
# train_accuracy  90.72916666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  109
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9435, device='cuda:0')
# train_accuracy  92.39583333333333 %
# test_accuracy  74.79166666666667 %
#
# Epoch  110
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4306, device='cuda:0')
# train_accuracy  93.75 %
# test_accuracy  75.72916666666667 %
#
# Epoch  111
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5703, device='cuda:0')
# train_accuracy  93.02083333333333 %
# test_accuracy  76.25 %
#
# Epoch  112
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0228, device='cuda:0')
# train_accuracy  94.375 %
# test_accuracy  73.64583333333333 %
#
# Epoch  113
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9043, device='cuda:0')
# train_accuracy  95.0 %
# test_accuracy  77.08333333333334 %
#
# Epoch  114
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7244, device='cuda:0')
# train_accuracy  95.625 %
# test_accuracy  76.45833333333333 %
#
# Epoch  115
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7056, device='cuda:0')
# train_accuracy  94.79166666666666 %
# test_accuracy  75.83333333333333 %
#
# Epoch  116
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6453, device='cuda:0')
# train_accuracy  95.625 %
# test_accuracy  76.5625 %
#
# Epoch  117
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2864, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  76.35416666666667 %
#
# Epoch  118
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5827, device='cuda:0')
# train_accuracy  95.83333333333334 %
# test_accuracy  78.22916666666667 %
#
# Epoch  119
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4722, device='cuda:0')
# train_accuracy  95.9375 %
# test_accuracy  76.66666666666667 %
#
# Epoch  120
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1872, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  76.35416666666667 %
#
# Epoch  121
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2701, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  75.83333333333333 %
#
# Epoch  122
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3344, device='cuda:0')
# train_accuracy  96.25 %
# test_accuracy  74.89583333333333 %
#
# Epoch  123
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2040, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  76.45833333333333 %
#
# Epoch  124
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1347, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  75.52083333333334 %
#
# Epoch  125
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1779, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  76.25 %
#
# Epoch  126
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2988, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  75.72916666666667 %
#
# Epoch  127
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0675, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  76.25 %
#
# Epoch  128
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1916, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  77.08333333333334 %
#
# Epoch  129
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3595, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  75.41666666666667 %
#
# Epoch  130
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2288, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  74.79166666666667 %
#
# Epoch  131
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2478, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  76.25 %
#
# Epoch  132
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2497, device='cuda:0')
# train_accuracy  96.5625 %
# test_accuracy  74.27083333333333 %
#
# Epoch  133
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8156, device='cuda:0')
# train_accuracy  94.89583333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  134
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5955, device='cuda:0')
# train_accuracy  96.04166666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  135
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9047, device='cuda:0')
# train_accuracy  93.02083333333333 %
# test_accuracy  70.20833333333333 %
#
# Epoch  136
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.7170, device='cuda:0')
# train_accuracy  92.60416666666667 %
# test_accuracy  74.58333333333333 %
#
# Epoch  137
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9387, device='cuda:0')
# train_accuracy  91.97916666666667 %
# test_accuracy  66.66666666666666 %
#
# Epoch  138
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6733, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  76.875 %
#
# Epoch  139
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0017, device='cuda:0')
# train_accuracy  90.0 %
# test_accuracy  70.20833333333333 %
#
# Epoch  140
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0404, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  69.89583333333333 %
#
# Epoch  141
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5368, device='cuda:0')
# train_accuracy  90.52083333333333 %
# test_accuracy  76.25 %
#
# Epoch  142
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6233, device='cuda:0')
# train_accuracy  90.72916666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  143
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2589, device='cuda:0')
# train_accuracy  91.45833333333333 %
# test_accuracy  71.35416666666666 %
#
# Epoch  144
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1353, device='cuda:0')
# train_accuracy  94.79166666666666 %
# test_accuracy  77.1875 %
#
# Epoch  145
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3941, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  75.10416666666667 %
#
# Epoch  146
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0471, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  76.25 %
#
# Epoch  147
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1503, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  77.29166666666667 %
#
# Epoch  148
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8545, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  77.39583333333333 %
#
# Epoch  149
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7993, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.14583333333333 %
#
# Epoch  150
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8864, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.875 %
#
# Epoch  151
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8244, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  76.77083333333333 %
#
# Epoch  152
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7201, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  78.02083333333333 %
#
# Epoch  153
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7883, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  79.16666666666666 %
#
# Epoch  154
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0167, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  76.25 %
#
# Epoch  155
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7782, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  75.83333333333333 %
#
# Epoch  156
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7216, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  77.5 %
#
# Epoch  157
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7861, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.35416666666667 %
#
# Epoch  158
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8600, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  76.77083333333333 %
#
# Epoch  159
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8481, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  76.04166666666666 %
#
# Epoch  160
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7535, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  75.3125 %
#
# Epoch  161
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9037, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  76.35416666666667 %
#
# Epoch  162
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7794, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  76.66666666666667 %
#
# Epoch  163
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8142, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  77.91666666666667 %
#
# Epoch  164
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6390, device='cuda:0')
# train_accuracy  99.16666666666667 %
# test_accuracy  75.10416666666667 %
#
# Epoch  165
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9235, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  77.29166666666667 %
#
# Epoch  166
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7467, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  75.625 %
#
# Epoch  167
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9179, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  75.20833333333333 %
#
# Epoch  168
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5557, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  77.5 %
#
# Epoch  169
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7254, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  77.1875 %
#
# Epoch  170
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6805, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  76.5625 %
#
# Epoch  171
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7378, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  76.66666666666667 %
#
# Epoch  172
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6606, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  75.83333333333333 %
#
# Epoch  173
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6228, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  76.875 %
#
# Epoch  174
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5778, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  77.39583333333333 %
#
# Epoch  175
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5765, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  76.66666666666667 %
#
# Epoch  176
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7137, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.875 %
#
# Epoch  177
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8152, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  74.79166666666667 %
#
# Epoch  178
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8263, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.66666666666667 %
#
# Epoch  179
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5436, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  75.52083333333334 %
#
# Epoch  180
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7303, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  75.3125 %
#
# Epoch  181
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6898, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.04166666666666 %
#
# Epoch  182
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8699, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  76.14583333333333 %
#
# Epoch  183
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7149, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  76.35416666666667 %
#
# Epoch  184
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6713, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  77.29166666666667 %
#
# Epoch  185
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5735, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  76.5625 %
#
# Epoch  186
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5012, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  77.39583333333333 %
#
# Epoch  187
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4727, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  76.77083333333333 %
#
# Epoch  188
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6982, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.04166666666666 %
#
# Epoch  189
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7186, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  76.35416666666667 %
#
# Epoch  190
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8467, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  74.16666666666667 %
#
# Epoch  191
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8229, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  74.58333333333333 %
#
# Epoch  192
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6886, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  78.02083333333333 %
#
# Epoch  193
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6387, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  76.5625 %
#
# Epoch  194
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5897, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  195
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6027, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  77.60416666666666 %
#
# Epoch  196
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6474, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  75.625 %
#
# Epoch  197
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6496, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  76.5625 %
#
# Epoch  198
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5283, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  75.0 %
#
# Epoch  199
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4890, device='cuda:0')
# train_accuracy  99.16666666666667 %
# test_accuracy  76.35416666666667 %
#
# Epoch  200
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6281, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  76.66666666666667 %
#
# Epoch  201
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7479, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  76.04166666666666 %
#
# Epoch  202
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6576, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.45833333333333 %
#
# Epoch  203
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8278, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  78.64583333333334 %
#
# Epoch  204
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0271, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  205
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8719, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  75.52083333333334 %
#
# Epoch  206
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6748, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  75.9375 %
#
# Epoch  207
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0417, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  74.375 %
#
# Epoch  208
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7728, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.875 %
#
# Epoch  209
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5041, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  77.1875 %
#
# Epoch  210
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4559, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  76.77083333333333 %
#
# Epoch  211
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4794, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  76.5625 %
#
# Epoch  212
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4511, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.875 %
#
# Epoch  213
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4690, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  76.25 %
#
# Epoch  214
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3904, device='cuda:0')
# train_accuracy  99.47916666666666 %
# test_accuracy  76.66666666666667 %
#
# Epoch  215
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3605, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  75.41666666666667 %
#
# Epoch  216
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4038, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  76.25 %
#
# Epoch  217
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4425, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  78.4375 %
#
# Epoch  218
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3990, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  75.41666666666667 %
#
# Epoch  219
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4493, device='cuda:0')
# train_accuracy  99.58333333333333 %
# test_accuracy  76.5625 %
#
# Epoch  220
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4463, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  76.5625 %
#
# Epoch  221
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5378, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  77.1875 %
#
# Epoch  222
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5956, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  78.125 %
#
# Epoch  223
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5794, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  74.375 %
#
# Epoch  224
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5366, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  76.14583333333333 %
#
# Epoch  225
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6373, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  76.97916666666667 %
#
# Epoch  226
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7442, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  76.45833333333333 %
#
# Epoch  227
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5788, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  76.14583333333333 %
#
# Epoch  228
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7417, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  75.625 %
#
# Epoch  229
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9272, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  76.5625 %
#
# Epoch  230
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6896, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  75.41666666666667 %
#
# Epoch  231
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9145, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  75.41666666666667 %
#
# Epoch  232
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9615, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  75.0 %
#
# Epoch  233
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9287, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  75.83333333333333 %
#
# Epoch  234
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7672, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  75.0 %
#
# Epoch  235
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6672, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  236
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6875, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  76.875 %
#
# Epoch  237
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3717, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  75.10416666666667 %
#
# Epoch  238
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5130, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  77.91666666666667 %
#
# Epoch  239
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6193, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.14583333333333 %
#
# Epoch  240
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4531, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  75.9375 %
#
# Epoch  241
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3853, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  76.04166666666666 %
#
# Epoch  242
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6661, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  75.52083333333334 %
#
# Epoch  243
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4582, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  76.45833333333333 %
#
# Epoch  244
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3773, device='cuda:0')
# train_accuracy  99.47916666666666 %
# test_accuracy  75.0 %
#
# Epoch  245
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3389, device='cuda:0')
# train_accuracy  99.47916666666666 %
# test_accuracy  76.04166666666666 %
#
# Epoch  246
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4215, device='cuda:0')
# train_accuracy  99.16666666666667 %
# test_accuracy  75.52083333333334 %
#
# Epoch  247
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3143, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  75.83333333333333 %
#
# Epoch  248
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3442, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  78.33333333333333 %
#
# Epoch  249
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3622, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  77.1875 %
#
# Epoch  250
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4114, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.97916666666667 %
#
# Epoch  251
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4438, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  76.04166666666666 %
#
# Epoch  252
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3074, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  76.45833333333333 %
#
# Epoch  253
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4640, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  74.58333333333333 %
#
# Epoch  254
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6781, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  77.1875 %
#
# Epoch  255
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8033, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  77.1875 %
#
# Epoch  256
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5745, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  75.625 %
#
# Epoch  257
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5553, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  76.25 %
#
# Epoch  258
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4295, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  75.0 %
#
# Epoch  259
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5222, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  73.85416666666667 %
#
# Epoch  260
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7382, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  76.25 %
#
# Epoch  261
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7794, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  76.25 %
#
# Epoch  262
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7559, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  74.0625 %
#
# Epoch  263
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9742, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  75.83333333333333 %
#
# Epoch  264
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9098, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  76.14583333333333 %
#
# Epoch  265
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0089, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  76.5625 %
#
# Epoch  266
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5788, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  74.16666666666667 %
#
# Epoch  267
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7754, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  77.70833333333333 %
#
# Epoch  268
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8200, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  75.625 %
#
# Epoch  269
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5682, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  75.72916666666667 %
#
# Epoch  270
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6559, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  76.5625 %
#
# Epoch  271
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6091, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  75.41666666666667 %
#
# Epoch  272
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9425, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  75.10416666666667 %
#
# Epoch  273
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7702, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  74.16666666666667 %
#
# Epoch  274
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8071, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  74.79166666666667 %
#
# Epoch  275
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7426, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  77.08333333333334 %
#
# Epoch  276
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4662, device='cuda:0')
# train_accuracy  98.85416666666667 %
# test_accuracy  73.4375 %
#
# Epoch  277
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5665, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  75.83333333333333 %
#
# Epoch  278
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5976, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  75.0 %
#
# Epoch  279
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3968, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  75.3125 %
#
# Epoch  280
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2874, device='cuda:0')
# train_accuracy  99.58333333333333 %
# test_accuracy  75.83333333333333 %
#
# Epoch  281
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2843, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  76.14583333333333 %
#
# Epoch  282
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4162, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  77.91666666666667 %
#
# Epoch  283
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2922, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  77.91666666666667 %
#
# Epoch  284
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2482, device='cuda:0')
# train_accuracy  99.58333333333333 %
# test_accuracy  76.77083333333333 %
#
# Epoch  285
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2123, device='cuda:0')
# train_accuracy  99.6875 %
# test_accuracy  77.08333333333334 %
#
# Epoch  286
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2192, device='cuda:0')
# train_accuracy  99.6875 %
# test_accuracy  76.97916666666667 %
#
# Epoch  287
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2964, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  77.5 %
#
# Epoch  288
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3849, device='cuda:0')
# train_accuracy  99.58333333333333 %
# test_accuracy  77.29166666666667 %
#
# Epoch  289
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3206, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  75.52083333333334 %
#
# Epoch  290
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5354, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  75.41666666666667 %
#
# Epoch  291
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4035, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  77.5 %
#
# Epoch  292
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3000, device='cuda:0')
# train_accuracy  99.375 %
# test_accuracy  76.97916666666667 %
#
# Epoch  293
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4073, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  78.125 %
#
# Epoch  294
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4503, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  77.91666666666667 %
#
# Epoch  295
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.4323, device='cuda:0')
# train_accuracy  99.16666666666667 %
# test_accuracy  76.97916666666667 %
#
# Epoch  296
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.2193, device='cuda:0')
# train_accuracy  99.6875 %
# test_accuracy  78.54166666666667 %
#
# Epoch  297
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.3627, device='cuda:0')
# train_accuracy  99.27083333333333 %
# test_accuracy  77.70833333333333 %
#
# Epoch  298
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5682, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  76.04166666666666 %
#
# Epoch  299
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5126, device='cuda:0')
# train_accuracy  98.95833333333334 %
# test_accuracy  78.85416666666667 %
