# %%
import numpy as np 
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import dataloader as da

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 120

        # Layer 1
        self.conv1 = nn.Conv2d(1, 16, kernel_size = (1, 51), stride = (1, 1), padding = (0, 25), bias = False)
        self.batchnorm1 = nn.BatchNorm2d(16, eps = 1e-03, momentum=0.1, affine= True, track_running_stats=True)
        
        # Layer 2
        self.conv2 = nn.Conv2d(16, 32, kernel_size = (2, 1), stride = (1, 1), groups = 16, bias = False)
        self.batchnorm2 = nn.BatchNorm2d(32, eps = 1e-02, momentum = 0.1, affine = True, track_running_stats = True)
        self.pooling2 = nn.AvgPool2d(kernel_size=(1, 4), stride = (1, 4), padding = 0)
        
        # Layer 3
        self.conv3 = nn.Conv2d(32, 32, kernel_size = (1, 15), stride = (1, 1), padding = (0, 7), bias = False)
        self.batchnorm3 = nn.BatchNorm2d(32, eps = 1e-05, momentum = 0.1, affine = True, track_running_stats = True)
        self.pooling3 = nn.AvgPool2d(kernel_size = (1, 8), stride = (1, 8), padding = 0)
        
        # FC Layer
        # NOTE: This dimension will depend on the number of timestamps per sample in your data.
        # I have 120 timepoints. 
        self.fc1 = nn.Linear(in_features = 736, out_features = 1, bias = True)
        
    def forward(self, x):

        # Layer 1
        x = self.conv1(x)
        x = self.batchnorm1(x)
       
        # Layer 2
        x = self.conv2(x)
        x = self.batchnorm2(x)
        x = F.elu(x, 1.0)
        x = self.pooling2(x)
        x = F.dropout(x, 0.25)
       
        # Layer 3
        x = self.conv3(x)
        x = self.batchnorm3(x)
        x = F.elu(x, 1.0)
        x = self.pooling3(x)
        x = F.dropout(x, 0.25)

        
        # FC Layer
        x = x.view(-1, 736)
        x = self.fc1(x)
        x = F.sigmoid(x)
        
        return x

# %%
def evaluate(model, X, Y, params = ["acc"]):
    results = []
    batch_size = 64
    
    predicted = []
    
    for i in range(int(len(X)/batch_size)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = Variable(torch.from_numpy(X[s:e]).cuda(0))
        pred = model(inputs)
        
        predicted.append(pred.data.cpu().numpy())
        
        
    inputs = Variable(torch.from_numpy(X).cuda(0))
    predicted = model(inputs)
    
    predicted = predicted.data.cpu().numpy()
    
    for param in params:
        if param == 'acc':
            results.append(accuracy_score(Y, np.round(predicted)))
        if param == "auc":
            results.append(roc_auc_score(Y, predicted))
        if param == "recall":
            results.append(recall_score(Y, np.round(predicted)))
        if param == "precision":
            results.append(precision_score(Y, np.round(predicted)))
        if param == "fmeasure":
            precision = precision_score(Y, np.round(predicted))
            recall = recall_score(Y, np.round(predicted))
            results.append(2*precision*recall/ (precision+recall))
    return results

# %%
X_train, y_train, X_test, y_test = da.read_bci_data()
# Out:
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)

# %%
batch_size = 64
net = EEGNet().cuda(0)
criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())
train_output = []
test_output = []

for epoch in range(300):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    running_loss = 0.0
    for i in range(int(len(X_train)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_train[s:e]).float()
        labels = torch.FloatTensor(np.array([y_train[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        train_output += outputs.T.tolist()[0]

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.data
    
    for i in range(int(len(X_test)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_test[s:e]).float()
        labels = torch.FloatTensor(np.array([y_test[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        test_output += outputs.T.tolist()[0]


    train_accuracy = accuracy_score(np.array(y_train[0:960]), np.array(train_output).round())        
    train_output = []
    test_accuracy = accuracy_score(np.array(y_test[0:960]), np.array(test_output).round())    
    test_output = []
    
    # Validation accuracy
    params = ["acc", "auc", "fmeasure"]
    print(params) 
    print("Training Loss ", running_loss)
    print("train_accuracy ", train_accuracy*100, "%")
    print("test_accuracy ", test_accuracy*100, "%")   
#     print("Train - ", evaluate(net, X_train, y_train, params))
#     print("Validation - ", evaluate(net, X_val, y_val, params))
#     print("Test - ", evaluate(net, X_test, y_test, params))
# Out:
# Epoch  0
# /root/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(9.8116, device='cuda:0')
# train_accuracy  61.5625 %
# test_accuracy  72.08333333333333 %
#
# Epoch  1
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.7111, device='cuda:0')
# train_accuracy  74.27083333333333 %
# test_accuracy  70.72916666666667 %
#
# Epoch  2
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.3534, device='cuda:0')
# train_accuracy  75.41666666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  3
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.0558, device='cuda:0')
# train_accuracy  77.8125 %
# test_accuracy  73.33333333333333 %
#
# Epoch  4
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9102, device='cuda:0')
# train_accuracy  78.85416666666667 %
# test_accuracy  71.97916666666667 %
#
# Epoch  5
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7900, device='cuda:0')
# train_accuracy  79.375 %
# test_accuracy  72.39583333333334 %
#
# Epoch  6
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6487, device='cuda:0')
# train_accuracy  79.0625 %
# test_accuracy  72.70833333333333 %
#
# Epoch  7
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5111, device='cuda:0')
# train_accuracy  78.64583333333334 %
# test_accuracy  73.85416666666667 %
#
# Epoch  8
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.4700, device='cuda:0')
# train_accuracy  79.89583333333333 %
# test_accuracy  73.22916666666667 %
#
# Epoch  9
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5545, device='cuda:0')
# train_accuracy  79.79166666666667 %
# test_accuracy  74.16666666666667 %
#
# Epoch  10
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2932, device='cuda:0')
# train_accuracy  80.41666666666667 %
# test_accuracy  73.125 %
#
# Epoch  11
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1572, device='cuda:0')
# train_accuracy  81.14583333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  12
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1928, device='cuda:0')
# train_accuracy  80.9375 %
# test_accuracy  73.125 %
#
# Epoch  13
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1345, device='cuda:0')
# train_accuracy  80.9375 %
# test_accuracy  73.4375 %
#
# Epoch  14
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0368, device='cuda:0')
# train_accuracy  81.14583333333333 %
# test_accuracy  73.4375 %
#
# Epoch  15
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9747, device='cuda:0')
# train_accuracy  80.83333333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  16
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9093, device='cuda:0')
# train_accuracy  82.29166666666666 %
# test_accuracy  73.85416666666667 %
#
# Epoch  17
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9467, device='cuda:0')
# train_accuracy  81.875 %
# test_accuracy  74.47916666666666 %
#
# Epoch  18
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8537, device='cuda:0')
# train_accuracy  82.8125 %
# test_accuracy  74.6875 %
#
# Epoch  19
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8128, device='cuda:0')
# train_accuracy  81.97916666666667 %
# test_accuracy  73.85416666666667 %
#
# Epoch  20
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8706, device='cuda:0')
# train_accuracy  81.97916666666667 %
# test_accuracy  73.54166666666667 %
#
# Epoch  21
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6242, device='cuda:0')
# train_accuracy  83.54166666666667 %
# test_accuracy  74.79166666666667 %
#
# Epoch  22
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8874, device='cuda:0')
# train_accuracy  81.45833333333333 %
# test_accuracy  74.16666666666667 %
#
# Epoch  23
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6839, device='cuda:0')
# train_accuracy  82.08333333333333 %
# test_accuracy  73.64583333333333 %
#
# Epoch  24
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8725, device='cuda:0')
# train_accuracy  81.35416666666667 %
# test_accuracy  74.16666666666667 %
#
# Epoch  25
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5184, device='cuda:0')
# train_accuracy  84.16666666666667 %
# test_accuracy  74.47916666666666 %
#
# Epoch  26
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5335, device='cuda:0')
# train_accuracy  84.16666666666667 %
# test_accuracy  74.375 %
#
# Epoch  27
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2481, device='cuda:0')
# train_accuracy  84.0625 %
# test_accuracy  73.85416666666667 %
#
# Epoch  28
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3930, device='cuda:0')
# train_accuracy  82.60416666666667 %
# test_accuracy  74.6875 %
#
# Epoch  29
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2667, device='cuda:0')
# train_accuracy  84.0625 %
# test_accuracy  74.47916666666666 %
#
# Epoch  30
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1693, device='cuda:0')
# train_accuracy  84.27083333333333 %
# test_accuracy  75.3125 %
#
# Epoch  31
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1243, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  73.95833333333334 %
#
# Epoch  32
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0868, device='cuda:0')
# train_accuracy  83.85416666666666 %
# test_accuracy  74.58333333333333 %
#
# Epoch  33
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9228, device='cuda:0')
# train_accuracy  84.16666666666667 %
# test_accuracy  76.45833333333333 %
#
# Epoch  34
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8764, device='cuda:0')
# train_accuracy  84.79166666666667 %
# test_accuracy  76.04166666666666 %
#
# Epoch  35
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4832, device='cuda:0')
# train_accuracy  87.70833333333333 %
# test_accuracy  76.5625 %
#
# Epoch  36
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5957, device='cuda:0')
# train_accuracy  86.35416666666667 %
# test_accuracy  77.8125 %
#
# Epoch  37
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7577, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  77.39583333333333 %
#
# Epoch  38
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7751, device='cuda:0')
# train_accuracy  84.89583333333334 %
# test_accuracy  76.45833333333333 %
#
# Epoch  39
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5853, device='cuda:0')
# train_accuracy  87.70833333333333 %
# test_accuracy  76.5625 %
#
# Epoch  40
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7185, device='cuda:0')
# train_accuracy  86.45833333333334 %
# test_accuracy  76.66666666666667 %
#
# Epoch  41
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5839, device='cuda:0')
# train_accuracy  86.14583333333333 %
# test_accuracy  77.29166666666667 %
#
# Epoch  42
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3655, device='cuda:0')
# train_accuracy  86.875 %
# test_accuracy  77.70833333333333 %
#
# Epoch  43
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2437, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  76.77083333333333 %
#
# Epoch  44
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2629, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  78.64583333333334 %
#
# Epoch  45
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9477, device='cuda:0')
# train_accuracy  88.33333333333333 %
# test_accuracy  76.97916666666667 %
#
# Epoch  46
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1022, device='cuda:0')
# train_accuracy  88.22916666666667 %
# test_accuracy  77.91666666666667 %
#
# Epoch  47
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9964, device='cuda:0')
# train_accuracy  88.22916666666667 %
# test_accuracy  78.95833333333333 %
#
# Epoch  48
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1886, device='cuda:0')
# train_accuracy  86.97916666666666 %
# test_accuracy  78.75 %
#
# Epoch  49
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8712, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  78.75 %
#
# Epoch  50
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8956, device='cuda:0')
# train_accuracy  89.375 %
# test_accuracy  78.85416666666667 %
#
# Epoch  51
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7300, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  78.02083333333333 %
#
# Epoch  52
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6383, device='cuda:0')
# train_accuracy  90.41666666666667 %
# test_accuracy  79.0625 %
#
# Epoch  53
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7105, device='cuda:0')
# train_accuracy  90.10416666666666 %
# test_accuracy  77.91666666666667 %
#
# Epoch  54
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9768, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  76.66666666666667 %
#
# Epoch  55
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7865, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  77.8125 %
#
# Epoch  56
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4435, device='cuda:0')
# train_accuracy  90.3125 %
# test_accuracy  78.75 %
#
# Epoch  57
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6814, device='cuda:0')
# train_accuracy  89.47916666666667 %
# test_accuracy  78.75 %
#
# Epoch  58
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6786, device='cuda:0')
# train_accuracy  89.375 %
# test_accuracy  78.75 %
#
# Epoch  59
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7022, device='cuda:0')
# train_accuracy  89.0625 %
# test_accuracy  79.375 %
#
# Epoch  60
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5719, device='cuda:0')
# train_accuracy  89.6875 %
# test_accuracy  77.1875 %
#
# Epoch  61
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7498, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  78.22916666666667 %
#
# Epoch  62
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5725, device='cuda:0')
# train_accuracy  88.64583333333333 %
# test_accuracy  78.125 %
#
# Epoch  63
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4946, device='cuda:0')
# train_accuracy  89.79166666666667 %
# test_accuracy  78.75 %
#
# Epoch  64
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4443, device='cuda:0')
# train_accuracy  89.79166666666667 %
# test_accuracy  78.33333333333333 %
#
# Epoch  65
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2333, device='cuda:0')
# train_accuracy  91.97916666666667 %
# test_accuracy  77.91666666666667 %
#
# Epoch  66
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4609, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  78.125 %
#
# Epoch  67
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2087, device='cuda:0')
# train_accuracy  91.5625 %
# test_accuracy  79.47916666666667 %
#
# Epoch  68
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3713, device='cuda:0')
# train_accuracy  90.0 %
# test_accuracy  78.22916666666667 %
#
# Epoch  69
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9912, device='cuda:0')
# train_accuracy  92.1875 %
# test_accuracy  76.66666666666667 %
#
# Epoch  70
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9819, device='cuda:0')
# train_accuracy  92.29166666666667 %
# test_accuracy  78.4375 %
#
# Epoch  71
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2490, device='cuda:0')
# train_accuracy  91.25 %
# test_accuracy  78.75 %
#
# Epoch  72
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.1098, device='cuda:0')
# train_accuracy  92.29166666666667 %
# test_accuracy  79.375 %
#
# Epoch  73
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.1735, device='cuda:0')
# train_accuracy  91.77083333333333 %
# test_accuracy  80.20833333333334 %
#
# Epoch  74
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0640, device='cuda:0')
# train_accuracy  91.77083333333333 %
# test_accuracy  78.54166666666667 %
#
# Epoch  75
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9241, device='cuda:0')
# train_accuracy  92.29166666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  76
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0277, device='cuda:0')
# train_accuracy  92.5 %
# test_accuracy  79.79166666666667 %
#
# Epoch  77
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0861, device='cuda:0')
# train_accuracy  90.83333333333333 %
# test_accuracy  78.95833333333333 %
#
# Epoch  78
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.8451, device='cuda:0')
# train_accuracy  92.60416666666667 %
# test_accuracy  79.0625 %
#
# Epoch  79
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.7310, device='cuda:0')
# train_accuracy  93.125 %
# test_accuracy  79.89583333333333 %
#
# Epoch  80
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9835, device='cuda:0')
# train_accuracy  92.60416666666667 %
# test_accuracy  80.10416666666667 %
#
# Epoch  81
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.7229, device='cuda:0')
# train_accuracy  93.22916666666666 %
# test_accuracy  78.02083333333333 %
#
# Epoch  82
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.8710, device='cuda:0')
# train_accuracy  92.1875 %
# test_accuracy  79.27083333333333 %
#
# Epoch  83
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.8604, device='cuda:0')
# train_accuracy  93.125 %
# test_accuracy  78.54166666666667 %
#
# Epoch  84
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9548, device='cuda:0')
# train_accuracy  91.45833333333333 %
# test_accuracy  79.27083333333333 %
#
# Epoch  85
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2080, device='cuda:0')
# train_accuracy  91.04166666666667 %
# test_accuracy  78.33333333333333 %
#
# Epoch  86
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.2194, device='cuda:0')
# train_accuracy  90.9375 %
# test_accuracy  79.16666666666666 %
#
# Epoch  87
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9574, device='cuda:0')
# train_accuracy  91.97916666666667 %
# test_accuracy  78.4375 %
#
# Epoch  88
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4853, device='cuda:0')
# train_accuracy  90.0 %
# test_accuracy  78.85416666666667 %
#
# Epoch  89
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.0012, device='cuda:0')
# train_accuracy  92.1875 %
# test_accuracy  77.8125 %
#
# Epoch  90
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3966, device='cuda:0')
# train_accuracy  89.6875 %
# test_accuracy  78.02083333333333 %
#
# Epoch  91
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3130, device='cuda:0')
# train_accuracy  91.875 %
# test_accuracy  78.95833333333333 %
#
# Epoch  92
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3236, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  79.89583333333333 %
#
# Epoch  93
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.9271, device='cuda:0')
# train_accuracy  91.875 %
# test_accuracy  80.20833333333334 %
#
# Epoch  94
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4707, device='cuda:0')
# train_accuracy  93.95833333333333 %
# test_accuracy  80.10416666666667 %
#
# Epoch  95
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5162, device='cuda:0')
# train_accuracy  93.64583333333333 %
# test_accuracy  78.75 %
#
# Epoch  96
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5784, device='cuda:0')
# train_accuracy  93.75 %
# test_accuracy  79.0625 %
#
# Epoch  97
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.3810, device='cuda:0')
# train_accuracy  94.0625 %
# test_accuracy  80.41666666666667 %
#
# Epoch  98
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5029, device='cuda:0')
# train_accuracy  92.70833333333334 %
# test_accuracy  79.89583333333333 %
#
# Epoch  99
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2173, device='cuda:0')
# train_accuracy  94.79166666666666 %
# test_accuracy  78.125 %
#
# Epoch  100
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4250, device='cuda:0')
# train_accuracy  94.16666666666667 %
# test_accuracy  80.20833333333334 %
#
# Epoch  101
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.3961, device='cuda:0')
# train_accuracy  93.75 %
# test_accuracy  79.375 %
#
# Epoch  102
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5144, device='cuda:0')
# train_accuracy  93.22916666666666 %
# test_accuracy  80.3125 %
#
# Epoch  103
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2047, device='cuda:0')
# train_accuracy  94.79166666666666 %
# test_accuracy  78.85416666666667 %
#
# Epoch  104
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4578, device='cuda:0')
# train_accuracy  93.64583333333333 %
# test_accuracy  80.41666666666667 %
#
# Epoch  105
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2502, device='cuda:0')
# train_accuracy  94.16666666666667 %
# test_accuracy  78.85416666666667 %
#
# Epoch  106
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2870, device='cuda:0')
# train_accuracy  94.27083333333334 %
# test_accuracy  79.16666666666666 %
#
# Epoch  107
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2983, device='cuda:0')
# train_accuracy  93.75 %
# test_accuracy  79.58333333333333 %
#
# Epoch  108
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2996, device='cuda:0')
# train_accuracy  94.27083333333334 %
# test_accuracy  79.6875 %
#
# Epoch  109
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1840, device='cuda:0')
# train_accuracy  94.375 %
# test_accuracy  80.72916666666666 %
#
# Epoch  110
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0512, device='cuda:0')
# train_accuracy  94.16666666666667 %
# test_accuracy  80.10416666666667 %
#
# Epoch  111
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2779, device='cuda:0')
# train_accuracy  94.375 %
# test_accuracy  78.95833333333333 %
#
# Epoch  112
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9073, device='cuda:0')
# train_accuracy  95.3125 %
# test_accuracy  80.9375 %
#
# Epoch  113
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8519, device='cuda:0')
# train_accuracy  96.04166666666667 %
# test_accuracy  79.47916666666667 %
#
# Epoch  114
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0208, device='cuda:0')
# train_accuracy  95.10416666666667 %
# test_accuracy  80.625 %
#
# Epoch  115
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0065, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  79.58333333333333 %
#
# Epoch  116
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9800, device='cuda:0')
# train_accuracy  95.41666666666667 %
# test_accuracy  79.89583333333333 %
#
# Epoch  117
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9818, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  79.16666666666666 %
#
# Epoch  118
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1016, device='cuda:0')
# train_accuracy  94.58333333333333 %
# test_accuracy  77.8125 %
#
# Epoch  119
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2826, device='cuda:0')
# train_accuracy  94.375 %
# test_accuracy  80.20833333333334 %
#
# Epoch  120
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.1505, device='cuda:0')
# train_accuracy  94.6875 %
# test_accuracy  79.79166666666667 %
#
# Epoch  121
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.3411, device='cuda:0')
# train_accuracy  94.58333333333333 %
# test_accuracy  79.375 %
#
# Epoch  122
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.3881, device='cuda:0')
# train_accuracy  93.64583333333333 %
# test_accuracy  79.47916666666667 %
#
# Epoch  123
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.4132, device='cuda:0')
# train_accuracy  94.47916666666667 %
# test_accuracy  80.10416666666667 %
#
# Epoch  124
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.5086, device='cuda:0')
# train_accuracy  93.33333333333333 %
# test_accuracy  79.27083333333333 %
#
# Epoch  125
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.2193, device='cuda:0')
# train_accuracy  94.27083333333334 %
# test_accuracy  81.66666666666667 %
#
# Epoch  126
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0952, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  80.72916666666666 %
#
# Epoch  127
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8863, device='cuda:0')
# train_accuracy  95.3125 %
# test_accuracy  79.16666666666666 %
#
# Epoch  128
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8213, device='cuda:0')
# train_accuracy  95.83333333333334 %
# test_accuracy  79.0625 %
#
# Epoch  129
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7525, device='cuda:0')
# train_accuracy  96.35416666666666 %
# test_accuracy  80.20833333333334 %
#
# Epoch  130
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9722, device='cuda:0')
# train_accuracy  94.89583333333333 %
# test_accuracy  79.16666666666666 %
#
# Epoch  131
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6925, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  80.625 %
#
# Epoch  132
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6561, device='cuda:0')
# train_accuracy  95.52083333333333 %
# test_accuracy  80.83333333333333 %
#
# Epoch  133
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8612, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  81.45833333333333 %
#
# Epoch  134
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8068, device='cuda:0')
# train_accuracy  95.72916666666667 %
# test_accuracy  81.04166666666667 %
#
# Epoch  135
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0135, device='cuda:0')
# train_accuracy  94.6875 %
# test_accuracy  78.75 %
#
# Epoch  136
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8255, device='cuda:0')
# train_accuracy  95.52083333333333 %
# test_accuracy  80.20833333333334 %
#
# Epoch  137
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9380, device='cuda:0')
# train_accuracy  95.0 %
# test_accuracy  80.0 %
#
# Epoch  138
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7728, device='cuda:0')
# train_accuracy  95.10416666666667 %
# test_accuracy  79.47916666666667 %
#
# Epoch  139
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6851, device='cuda:0')
# train_accuracy  96.25 %
# test_accuracy  80.83333333333333 %
#
# Epoch  140
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5795, device='cuda:0')
# train_accuracy  95.625 %
# test_accuracy  79.16666666666666 %
#
# Epoch  141
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7545, device='cuda:0')
# train_accuracy  95.72916666666667 %
# test_accuracy  79.47916666666667 %
#
# Epoch  142
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8126, device='cuda:0')
# train_accuracy  95.41666666666667 %
# test_accuracy  81.45833333333333 %
#
# Epoch  143
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7245, device='cuda:0')
# train_accuracy  95.9375 %
# test_accuracy  81.35416666666667 %
#
# Epoch  144
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8784, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  81.25 %
#
# Epoch  145
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7701, device='cuda:0')
# train_accuracy  95.83333333333334 %
# test_accuracy  79.89583333333333 %
#
# Epoch  146
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5518, device='cuda:0')
# train_accuracy  96.25 %
# test_accuracy  79.16666666666666 %
#
# Epoch  147
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4874, device='cuda:0')
# train_accuracy  96.66666666666667 %
# test_accuracy  80.20833333333334 %
#
# Epoch  148
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5673, device='cuda:0')
# train_accuracy  96.66666666666667 %
# test_accuracy  81.97916666666667 %
#
# Epoch  149
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5539, device='cuda:0')
# train_accuracy  96.14583333333333 %
# test_accuracy  81.45833333333333 %
#
# Epoch  150
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4818, device='cuda:0')
# train_accuracy  96.45833333333333 %
# test_accuracy  80.9375 %
#
# Epoch  151
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7295, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  80.625 %
#
# Epoch  152
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6260, device='cuda:0')
# train_accuracy  95.9375 %
# test_accuracy  81.25 %
#
# Epoch  153
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7157, device='cuda:0')
# train_accuracy  95.9375 %
# test_accuracy  79.375 %
#
# Epoch  154
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6649, device='cuda:0')
# train_accuracy  96.04166666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  155
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7856, device='cuda:0')
# train_accuracy  95.20833333333333 %
# test_accuracy  81.35416666666667 %
#
# Epoch  156
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.8025, device='cuda:0')
# train_accuracy  95.52083333333333 %
# test_accuracy  80.83333333333333 %
#
# Epoch  157
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.9247, device='cuda:0')
# train_accuracy  94.6875 %
# test_accuracy  80.3125 %
#
# Epoch  158
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7689, device='cuda:0')
# train_accuracy  94.89583333333333 %
# test_accuracy  81.25 %
#
# Epoch  159
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(2.0463, device='cuda:0')
# train_accuracy  94.6875 %
# test_accuracy  80.20833333333334 %
#
# Epoch  160
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.6197, device='cuda:0')
# train_accuracy  96.25 %
# test_accuracy  81.14583333333333 %
#
# Epoch  161
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7717, device='cuda:0')
# train_accuracy  95.10416666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  162
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.7432, device='cuda:0')
# train_accuracy  95.72916666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  163
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3865, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  81.77083333333334 %
#
# Epoch  164
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5975, device='cuda:0')
# train_accuracy  96.45833333333333 %
# test_accuracy  78.64583333333334 %
#
# Epoch  165
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5244, device='cuda:0')
# train_accuracy  96.35416666666666 %
# test_accuracy  79.79166666666667 %
#
# Epoch  166
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4305, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  80.3125 %
#
# Epoch  167
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4216, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  80.41666666666667 %
#
# Epoch  168
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3499, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  80.0 %
#
# Epoch  169
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4394, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.625 %
#
# Epoch  170
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5095, device='cuda:0')
# train_accuracy  96.35416666666666 %
# test_accuracy  79.79166666666667 %
#
# Epoch  171
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2264, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  79.89583333333333 %
#
# Epoch  172
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3495, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  79.6875 %
#
# Epoch  173
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2955, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.52083333333333 %
#
# Epoch  174
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1695, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  81.04166666666667 %
#
# Epoch  175
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2462, device='cuda:0')
# train_accuracy  96.66666666666667 %
# test_accuracy  80.52083333333333 %
#
# Epoch  176
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3036, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  81.14583333333333 %
#
# Epoch  177
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2647, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  80.83333333333333 %
#
# Epoch  178
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2938, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  80.625 %
#
# Epoch  179
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3742, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  79.6875 %
#
# Epoch  180
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4160, device='cuda:0')
# train_accuracy  96.66666666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  181
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2433, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  79.0625 %
#
# Epoch  182
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.5437, device='cuda:0')
# train_accuracy  96.04166666666667 %
# test_accuracy  80.10416666666667 %
#
# Epoch  183
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3915, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  79.47916666666667 %
#
# Epoch  184
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2825, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  79.89583333333333 %
#
# Epoch  185
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3844, device='cuda:0')
# train_accuracy  96.35416666666666 %
# test_accuracy  79.89583333333333 %
#
# Epoch  186
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.4302, device='cuda:0')
# train_accuracy  96.5625 %
# test_accuracy  80.9375 %
#
# Epoch  187
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1955, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  80.83333333333333 %
#
# Epoch  188
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1586, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  80.52083333333333 %
#
# Epoch  189
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3710, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  80.3125 %
#
# Epoch  190
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2538, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.0 %
#
# Epoch  191
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1468, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  79.79166666666667 %
#
# Epoch  192
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2654, device='cuda:0')
# train_accuracy  96.45833333333333 %
# test_accuracy  80.0 %
#
# Epoch  193
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3689, device='cuda:0')
# train_accuracy  96.45833333333333 %
# test_accuracy  80.10416666666667 %
#
# Epoch  194
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2928, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  79.58333333333333 %
#
# Epoch  195
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2495, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  81.66666666666667 %
#
# Epoch  196
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0588, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  80.41666666666667 %
#
# Epoch  197
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1736, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  81.25 %
#
# Epoch  198
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1564, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  79.16666666666666 %
#
# Epoch  199
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3386, device='cuda:0')
# train_accuracy  96.25 %
# test_accuracy  80.72916666666666 %
#
# Epoch  200
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0251, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  79.79166666666667 %
#
# Epoch  201
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0484, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  77.91666666666667 %
#
# Epoch  202
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1798, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.625 %
#
# Epoch  203
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1473, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  79.16666666666666 %
#
# Epoch  204
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1341, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  78.85416666666667 %
#
# Epoch  205
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2932, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  79.58333333333333 %
#
# Epoch  206
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0646, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  81.45833333333333 %
#
# Epoch  207
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0352, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  78.85416666666667 %
#
# Epoch  208
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3017, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.3125 %
#
# Epoch  209
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2568, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  78.54166666666667 %
#
# Epoch  210
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0948, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  79.89583333333333 %
#
# Epoch  211
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0423, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  80.625 %
#
# Epoch  212
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1986, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  80.3125 %
#
# Epoch  213
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0891, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  80.9375 %
#
# Epoch  214
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2283, device='cuda:0')
# train_accuracy  97.29166666666667 %
# test_accuracy  79.0625 %
#
# Epoch  215
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1801, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.0 %
#
# Epoch  216
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1127, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.41666666666667 %
#
# Epoch  217
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1190, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  80.20833333333334 %
#
# Epoch  218
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1371, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  79.79166666666667 %
#
# Epoch  219
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.3800, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  79.79166666666667 %
#
# Epoch  220
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1006, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  80.52083333333333 %
#
# Epoch  221
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9994, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  79.375 %
#
# Epoch  222
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9943, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.9375 %
#
# Epoch  223
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0913, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  80.52083333333333 %
#
# Epoch  224
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0844, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  81.35416666666667 %
#
# Epoch  225
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9445, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  80.10416666666667 %
#
# Epoch  226
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.2101, device='cuda:0')
# train_accuracy  96.35416666666666 %
# test_accuracy  80.83333333333333 %
#
# Epoch  227
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1921, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  82.1875 %
#
# Epoch  228
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1112, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  229
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1858, device='cuda:0')
# train_accuracy  96.875 %
# test_accuracy  80.3125 %
#
# Epoch  230
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9783, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  80.3125 %
#
# Epoch  231
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8481, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  80.625 %
#
# Epoch  232
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0654, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  77.29166666666667 %
#
# Epoch  233
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9916, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  80.9375 %
#
# Epoch  234
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8476, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  79.89583333333333 %
#
# Epoch  235
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8318, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  80.20833333333334 %
#
# Epoch  236
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9087, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  81.45833333333333 %
#
# Epoch  237
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9297, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  79.27083333333333 %
#
# Epoch  238
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8296, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  80.83333333333333 %
#
# Epoch  239
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8280, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  80.10416666666667 %
#
# Epoch  240
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9838, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  79.375 %
#
# Epoch  241
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8442, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  79.79166666666667 %
#
# Epoch  242
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0797, device='cuda:0')
# train_accuracy  97.08333333333333 %
# test_accuracy  81.04166666666667 %
#
# Epoch  243
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9013, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  81.45833333333333 %
#
# Epoch  244
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1392, device='cuda:0')
# train_accuracy  96.77083333333333 %
# test_accuracy  80.3125 %
#
# Epoch  245
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9034, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  81.45833333333333 %
#
# Epoch  246
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9984, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  78.85416666666667 %
#
# Epoch  247
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0361, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  81.875 %
#
# Epoch  248
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9741, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  80.83333333333333 %
#
# Epoch  249
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.1050, device='cuda:0')
# train_accuracy  97.1875 %
# test_accuracy  81.04166666666667 %
#
# Epoch  250
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0092, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  79.375 %
#
# Epoch  251
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0171, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  80.52083333333333 %
#
# Epoch  252
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9446, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  80.52083333333333 %
#
# Epoch  253
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8955, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  81.875 %
#
# Epoch  254
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9362, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  80.3125 %
#
# Epoch  255
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9725, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  80.41666666666667 %
#
# Epoch  256
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7844, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  80.9375 %
#
# Epoch  257
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7087, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  79.27083333333333 %
#
# Epoch  258
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8979, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.41666666666667 %
#
# Epoch  259
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7886, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  80.3125 %
#
# Epoch  260
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7534, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  81.04166666666667 %
#
# Epoch  261
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8199, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  79.6875 %
#
# Epoch  262
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7927, device='cuda:0')
# train_accuracy  98.02083333333333 %
# test_accuracy  81.14583333333333 %
#
# Epoch  263
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9576, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  80.625 %
#
# Epoch  264
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8404, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  80.10416666666667 %
#
# Epoch  265
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8339, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  78.95833333333333 %
#
# Epoch  266
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0287, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  79.0625 %
#
# Epoch  267
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8791, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  80.41666666666667 %
#
# Epoch  268
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7770, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  80.9375 %
#
# Epoch  269
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9493, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.0 %
#
# Epoch  270
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0789, device='cuda:0')
# train_accuracy  96.97916666666667 %
# test_accuracy  79.58333333333333 %
#
# Epoch  271
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9330, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  80.83333333333333 %
#
# Epoch  272
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8353, device='cuda:0')
# train_accuracy  97.70833333333333 %
# test_accuracy  80.41666666666667 %
#
# Epoch  273
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9374, device='cuda:0')
# train_accuracy  97.60416666666667 %
# test_accuracy  80.9375 %
#
# Epoch  274
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6935, device='cuda:0')
# train_accuracy  99.0625 %
# test_accuracy  81.14583333333333 %
#
# Epoch  275
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7155, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  81.5625 %
#
# Epoch  276
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8145, device='cuda:0')
# train_accuracy  98.64583333333333 %
# test_accuracy  80.0 %
#
# Epoch  277
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8544, device='cuda:0')
# train_accuracy  98.4375 %
# test_accuracy  81.25 %
#
# Epoch  278
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7951, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  79.58333333333333 %
#
# Epoch  279
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8683, device='cuda:0')
# train_accuracy  97.39583333333334 %
# test_accuracy  81.45833333333333 %
#
# Epoch  280
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6896, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  79.58333333333333 %
#
# Epoch  281
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7956, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  80.9375 %
#
# Epoch  282
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6113, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  79.58333333333333 %
#
# Epoch  283
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7283, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  80.41666666666667 %
#
# Epoch  284
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8752, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  80.52083333333333 %
#
# Epoch  285
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8146, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  81.45833333333333 %
#
# Epoch  286
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8751, device='cuda:0')
# train_accuracy  97.5 %
# test_accuracy  79.375 %
#
# Epoch  287
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(1.0275, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  81.5625 %
#
# Epoch  288
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.9822, device='cuda:0')
# train_accuracy  97.91666666666666 %
# test_accuracy  80.20833333333334 %
#
# Epoch  289
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8329, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  81.35416666666667 %
#
# Epoch  290
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7421, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  81.45833333333333 %
#
# Epoch  291
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7200, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  79.16666666666666 %
#
# Epoch  292
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.8884, device='cuda:0')
# train_accuracy  97.8125 %
# test_accuracy  81.5625 %
#
# Epoch  293
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7597, device='cuda:0')
# train_accuracy  98.22916666666667 %
# test_accuracy  79.375 %
#
# Epoch  294
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7303, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  79.89583333333333 %
#
# Epoch  295
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7192, device='cuda:0')
# train_accuracy  98.33333333333333 %
# test_accuracy  81.25 %
#
# Epoch  296
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.5500, device='cuda:0')
# train_accuracy  99.16666666666667 %
# test_accuracy  81.35416666666667 %
#
# Epoch  297
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.6872, device='cuda:0')
# train_accuracy  98.75 %
# test_accuracy  80.72916666666666 %
#
# Epoch  298
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7817, device='cuda:0')
# train_accuracy  98.125 %
# test_accuracy  80.10416666666667 %
#
# Epoch  299
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(0.7268, device='cuda:0')
# train_accuracy  98.54166666666667 %
# test_accuracy  80.83333333333333 %
