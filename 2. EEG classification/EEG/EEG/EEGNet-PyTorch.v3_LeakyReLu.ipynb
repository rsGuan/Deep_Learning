# %%
import numpy as np 
from sklearn.metrics import roc_auc_score, precision_score, recall_score, accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import dataloader as da

# %%
class EEGNet(nn.Module):
    def __init__(self):
        super(EEGNet, self).__init__()
        self.T = 120

        # Layer 1
        self.conv1 = nn.Conv2d(1, 16, kernel_size = (1, 51), stride = (1, 1), padding = (0, 25), bias = False)
        self.batchnorm1 = nn.BatchNorm2d(16, eps = 1e-03, momentum=0.1, affine= True, track_running_stats=True)
        
        # Layer 2
        self.conv2 = nn.Conv2d(16, 32, kernel_size = (2, 1), stride = (1, 1), groups = 16, bias = False)
        self.batchnorm2 = nn.BatchNorm2d(32, eps = 1e-02, momentum = 0.1, affine = True, track_running_stats = True)
        self.pooling2 = nn.AvgPool2d(kernel_size=(1, 4), stride = (1, 4), padding = 0)
        
        # Layer 3
        self.conv3 = nn.Conv2d(32, 32, kernel_size = (1, 15), stride = (1, 1), padding = (0, 7), bias = False)
        self.batchnorm3 = nn.BatchNorm2d(32, eps = 1e-05, momentum = 0.1, affine = True, track_running_stats = True)
        self.pooling3 = nn.AvgPool2d(kernel_size = (1, 8), stride = (1, 8), padding = 0)
        
        # FC Layer
        # NOTE: This dimension will depend on the number of timestamps per sample in your data.
        # I have 120 timepoints. 
        self.fc1 = nn.Linear(in_features = 736, out_features = 1, bias = True)
        
    def forward(self, x):

        # Layer 1
        x = self.conv1(x)
        x = self.batchnorm1(x)
       
        # Layer 2
        x = self.conv2(x)
        x = self.batchnorm2(x)
        x = F.leaky_relu(x, 1.0)
        x = self.pooling2(x)
        x = F.dropout(x, 0.25)
       
        # Layer 3
        x = self.conv3(x)
        x = self.batchnorm3(x)
        x = F.leaky_relu(x, 1.0)
        x = self.pooling3(x)
        x = F.dropout(x, 0.25)

        
        # FC Layer
        x = x.view(-1, 736)
        x = self.fc1(x)
        x = F.sigmoid(x)
        
        return x

# %%
def evaluate(model, X, Y, params = ["acc"]):
    results = []
    batch_size = 64
    
    predicted = []
    
    for i in range(int(len(X)/batch_size)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = Variable(torch.from_numpy(X[s:e]).cuda(0))
        pred = model(inputs)
        
        predicted.append(pred.data.cpu().numpy())
        
        
    inputs = Variable(torch.from_numpy(X).cuda(0))
    predicted = model(inputs)
    
    predicted = predicted.data.cpu().numpy()
    
    for param in params:
        if param == 'acc':
            results.append(accuracy_score(Y, np.round(predicted)))
        if param == "auc":
            results.append(roc_auc_score(Y, predicted))
        if param == "recall":
            results.append(recall_score(Y, np.round(predicted)))
        if param == "precision":
            results.append(precision_score(Y, np.round(predicted)))
        if param == "fmeasure":
            precision = precision_score(Y, np.round(predicted))
            recall = recall_score(Y, np.round(predicted))
            results.append(2*precision*recall/ (precision+recall))
    return results

# %%
X_train, y_train, X_test, y_test = da.read_bci_data()
# Out:
# (1080, 1, 2, 750) (1080,) (1080, 1, 2, 750) (1080,)

# %%
batch_size = 64
net = EEGNet().cuda(0)
criterion = nn.BCELoss()
optimizer = optim.Adam(net.parameters())
train_output = []
test_output = []

for epoch in range(300):  # loop over the dataset multiple times
    print("\nEpoch ", epoch)
    
    running_loss = 0.0
    for i in range(int(len(X_train)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_train[s:e]).float()
        labels = torch.FloatTensor(np.array([y_train[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        train_output += outputs.T.tolist()[0]

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.data
    
    for i in range(int(len(X_test)/batch_size-1)):
        s = i*batch_size
        e = i*batch_size+batch_size
        
        inputs = torch.from_numpy(X_test[s:e]).float()
        labels = torch.FloatTensor(np.array([y_test[s:e]]).T*1.0)
        
        # wrap them in Variable
        inputs, labels = Variable(inputs.cuda(0)), Variable(labels.cuda(0))

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        test_output += outputs.T.tolist()[0]


    train_accuracy = accuracy_score(np.array(y_train[0:960]), np.array(train_output).round())        
    train_output = []
    test_accuracy = accuracy_score(np.array(y_test[0:960]), np.array(test_output).round())    
    test_output = []
    
    # Validation accuracy
    params = ["acc", "auc", "fmeasure"]
    print(params) 
    print("Training Loss ", running_loss)
    print("train_accuracy ", train_accuracy*100, "%")
    print("test_accuracy ", test_accuracy*100, "%")   
#     print("Train - ", evaluate(net, X_train, y_train, params))
#     print("Validation - ", evaluate(net, X_val, y_val, params))
#     print("Test - ", evaluate(net, X_test, y_test, params))
# Out:
# Epoch  0
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(10.3131, device='cuda:0')
# train_accuracy  56.25 %
# test_accuracy  68.125 %
#
# Epoch  1
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1639: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(8.1260, device='cuda:0')
# train_accuracy  73.02083333333333 %
# test_accuracy  71.45833333333333 %
#
# Epoch  2
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.5045, device='cuda:0')
# train_accuracy  74.79166666666667 %
# test_accuracy  71.25 %
#
# Epoch  3
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.5482, device='cuda:0')
# train_accuracy  75.41666666666667 %
# test_accuracy  71.25 %
#
# Epoch  4
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.3926, device='cuda:0')
# train_accuracy  76.04166666666666 %
# test_accuracy  71.45833333333333 %
#
# Epoch  5
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.2216, device='cuda:0')
# train_accuracy  75.9375 %
# test_accuracy  71.45833333333333 %
#
# Epoch  6
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.3172, device='cuda:0')
# train_accuracy  75.625 %
# test_accuracy  71.04166666666667 %
#
# Epoch  7
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.2816, device='cuda:0')
# train_accuracy  77.5 %
# test_accuracy  70.83333333333334 %
#
# Epoch  8
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.2358, device='cuda:0')
# train_accuracy  76.97916666666667 %
# test_accuracy  70.72916666666667 %
#
# Epoch  9
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.0992, device='cuda:0')
# train_accuracy  76.66666666666667 %
# test_accuracy  71.25 %
#
# Epoch  10
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.1367, device='cuda:0')
# train_accuracy  76.97916666666667 %
# test_accuracy  71.45833333333333 %
#
# Epoch  11
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.1205, device='cuda:0')
# train_accuracy  76.35416666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  12
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.0882, device='cuda:0')
# train_accuracy  78.02083333333333 %
# test_accuracy  71.45833333333333 %
#
# Epoch  13
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(7.0362, device='cuda:0')
# train_accuracy  76.14583333333333 %
# test_accuracy  70.72916666666667 %
#
# Epoch  14
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9951, device='cuda:0')
# train_accuracy  77.8125 %
# test_accuracy  72.1875 %
#
# Epoch  15
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9877, device='cuda:0')
# train_accuracy  77.39583333333333 %
# test_accuracy  70.52083333333333 %
#
# Epoch  16
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9176, device='cuda:0')
# train_accuracy  77.91666666666667 %
# test_accuracy  71.14583333333333 %
#
# Epoch  17
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9091, device='cuda:0')
# train_accuracy  78.125 %
# test_accuracy  71.66666666666667 %
#
# Epoch  18
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7928, device='cuda:0')
# train_accuracy  78.22916666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  19
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9628, device='cuda:0')
# train_accuracy  77.8125 %
# test_accuracy  72.1875 %
#
# Epoch  20
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7564, device='cuda:0')
# train_accuracy  78.64583333333334 %
# test_accuracy  71.77083333333333 %
#
# Epoch  21
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7824, device='cuda:0')
# train_accuracy  78.02083333333333 %
# test_accuracy  71.97916666666667 %
#
# Epoch  22
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7274, device='cuda:0')
# train_accuracy  79.6875 %
# test_accuracy  72.1875 %
#
# Epoch  23
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.9951, device='cuda:0')
# train_accuracy  77.39583333333333 %
# test_accuracy  71.35416666666666 %
#
# Epoch  24
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.8125, device='cuda:0')
# train_accuracy  78.33333333333333 %
# test_accuracy  71.45833333333333 %
#
# Epoch  25
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6423, device='cuda:0')
# train_accuracy  78.85416666666667 %
# test_accuracy  71.45833333333333 %
#
# Epoch  26
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6790, device='cuda:0')
# train_accuracy  79.47916666666667 %
# test_accuracy  71.5625 %
#
# Epoch  27
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7666, device='cuda:0')
# train_accuracy  79.47916666666667 %
# test_accuracy  72.08333333333333 %
#
# Epoch  28
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5170, device='cuda:0')
# train_accuracy  78.95833333333333 %
# test_accuracy  71.97916666666667 %
#
# Epoch  29
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7229, device='cuda:0')
# train_accuracy  78.75 %
# test_accuracy  71.5625 %
#
# Epoch  30
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5861, device='cuda:0')
# train_accuracy  79.16666666666666 %
# test_accuracy  71.97916666666667 %
#
# Epoch  31
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5970, device='cuda:0')
# train_accuracy  78.64583333333334 %
# test_accuracy  71.66666666666667 %
#
# Epoch  32
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5552, device='cuda:0')
# train_accuracy  79.16666666666666 %
# test_accuracy  73.02083333333333 %
#
# Epoch  33
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5181, device='cuda:0')
# train_accuracy  79.27083333333333 %
# test_accuracy  72.39583333333334 %
#
# Epoch  34
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5796, device='cuda:0')
# train_accuracy  78.85416666666667 %
# test_accuracy  72.91666666666666 %
#
# Epoch  35
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.7167, device='cuda:0')
# train_accuracy  78.4375 %
# test_accuracy  74.6875 %
#
# Epoch  36
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.4954, device='cuda:0')
# train_accuracy  79.79166666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  37
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.6161, device='cuda:0')
# train_accuracy  79.79166666666667 %
# test_accuracy  72.91666666666666 %
#
# Epoch  38
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5165, device='cuda:0')
# train_accuracy  81.14583333333333 %
# test_accuracy  72.60416666666667 %
#
# Epoch  39
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3620, device='cuda:0')
# train_accuracy  81.04166666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  40
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3308, device='cuda:0')
# train_accuracy  80.10416666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  41
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.4944, device='cuda:0')
# train_accuracy  79.47916666666667 %
# test_accuracy  73.54166666666667 %
#
# Epoch  42
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2615, device='cuda:0')
# train_accuracy  80.83333333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  43
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3970, device='cuda:0')
# train_accuracy  80.83333333333333 %
# test_accuracy  73.33333333333333 %
#
# Epoch  44
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2467, device='cuda:0')
# train_accuracy  81.14583333333333 %
# test_accuracy  72.29166666666667 %
#
# Epoch  45
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3258, device='cuda:0')
# train_accuracy  79.79166666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  46
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.5586, device='cuda:0')
# train_accuracy  79.0625 %
# test_accuracy  73.125 %
#
# Epoch  47
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2278, device='cuda:0')
# train_accuracy  80.625 %
# test_accuracy  71.5625 %
#
# Epoch  48
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2363, device='cuda:0')
# train_accuracy  80.0 %
# test_accuracy  73.4375 %
#
# Epoch  49
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2410, device='cuda:0')
# train_accuracy  81.04166666666667 %
# test_accuracy  73.33333333333333 %
#
# Epoch  50
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.3475, device='cuda:0')
# train_accuracy  80.52083333333333 %
# test_accuracy  73.02083333333333 %
#
# Epoch  51
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2125, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  73.4375 %
#
# Epoch  52
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0484, device='cuda:0')
# train_accuracy  80.72916666666666 %
# test_accuracy  73.95833333333334 %
#
# Epoch  53
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1784, device='cuda:0')
# train_accuracy  81.25 %
# test_accuracy  73.125 %
#
# Epoch  54
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2114, device='cuda:0')
# train_accuracy  80.52083333333333 %
# test_accuracy  74.16666666666667 %
#
# Epoch  55
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9949, device='cuda:0')
# train_accuracy  82.5 %
# test_accuracy  72.91666666666666 %
#
# Epoch  56
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.2187, device='cuda:0')
# train_accuracy  81.5625 %
# test_accuracy  74.27083333333333 %
#
# Epoch  57
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1440, device='cuda:0')
# train_accuracy  81.25 %
# test_accuracy  72.60416666666667 %
#
# Epoch  58
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0147, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  73.54166666666667 %
#
# Epoch  59
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.1198, device='cuda:0')
# train_accuracy  82.5 %
# test_accuracy  73.75 %
#
# Epoch  60
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9487, device='cuda:0')
# train_accuracy  82.5 %
# test_accuracy  73.85416666666667 %
#
# Epoch  61
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9137, device='cuda:0')
# train_accuracy  82.60416666666667 %
# test_accuracy  72.91666666666666 %
#
# Epoch  62
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9920, device='cuda:0')
# train_accuracy  82.29166666666666 %
# test_accuracy  73.95833333333334 %
#
# Epoch  63
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0097, device='cuda:0')
# train_accuracy  81.35416666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  64
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7357, device='cuda:0')
# train_accuracy  83.75 %
# test_accuracy  72.8125 %
#
# Epoch  65
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0502, device='cuda:0')
# train_accuracy  80.0 %
# test_accuracy  72.60416666666667 %
#
# Epoch  66
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8882, device='cuda:0')
# train_accuracy  82.91666666666667 %
# test_accuracy  73.85416666666667 %
#
# Epoch  67
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7283, device='cuda:0')
# train_accuracy  82.1875 %
# test_accuracy  73.02083333333333 %
#
# Epoch  68
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8531, device='cuda:0')
# train_accuracy  83.02083333333333 %
# test_accuracy  74.27083333333333 %
#
# Epoch  69
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0143, device='cuda:0')
# train_accuracy  81.5625 %
# test_accuracy  72.8125 %
#
# Epoch  70
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7090, device='cuda:0')
# train_accuracy  83.125 %
# test_accuracy  75.20833333333333 %
#
# Epoch  71
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9783, device='cuda:0')
# train_accuracy  81.66666666666667 %
# test_accuracy  75.0 %
#
# Epoch  72
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(6.0261, device='cuda:0')
# train_accuracy  80.72916666666666 %
# test_accuracy  73.02083333333333 %
#
# Epoch  73
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8923, device='cuda:0')
# train_accuracy  81.875 %
# test_accuracy  74.27083333333333 %
#
# Epoch  74
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9661, device='cuda:0')
# train_accuracy  82.60416666666667 %
# test_accuracy  74.0625 %
#
# Epoch  75
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8758, device='cuda:0')
# train_accuracy  81.875 %
# test_accuracy  73.54166666666667 %
#
# Epoch  76
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8653, device='cuda:0')
# train_accuracy  82.29166666666666 %
# test_accuracy  74.375 %
#
# Epoch  77
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9169, device='cuda:0')
# train_accuracy  81.66666666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  78
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.9363, device='cuda:0')
# train_accuracy  82.29166666666666 %
# test_accuracy  72.5 %
#
# Epoch  79
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8394, device='cuda:0')
# train_accuracy  82.08333333333333 %
# test_accuracy  73.64583333333333 %
#
# Epoch  80
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6537, device='cuda:0')
# train_accuracy  82.5 %
# test_accuracy  72.70833333333333 %
#
# Epoch  81
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7588, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  72.08333333333333 %
#
# Epoch  82
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6813, device='cuda:0')
# train_accuracy  83.95833333333333 %
# test_accuracy  72.60416666666667 %
#
# Epoch  83
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7564, device='cuda:0')
# train_accuracy  82.91666666666667 %
# test_accuracy  74.47916666666666 %
#
# Epoch  84
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7221, device='cuda:0')
# train_accuracy  83.125 %
# test_accuracy  73.125 %
#
# Epoch  85
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6544, device='cuda:0')
# train_accuracy  81.77083333333334 %
# test_accuracy  73.95833333333334 %
#
# Epoch  86
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7333, device='cuda:0')
# train_accuracy  84.16666666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  87
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.8314, device='cuda:0')
# train_accuracy  83.64583333333333 %
# test_accuracy  73.75 %
#
# Epoch  88
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.7319, device='cuda:0')
# train_accuracy  83.125 %
# test_accuracy  72.1875 %
#
# Epoch  89
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6683, device='cuda:0')
# train_accuracy  83.85416666666666 %
# test_accuracy  72.70833333333333 %
#
# Epoch  90
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6350, device='cuda:0')
# train_accuracy  83.22916666666667 %
# test_accuracy  73.75 %
#
# Epoch  91
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6377, device='cuda:0')
# train_accuracy  82.39583333333333 %
# test_accuracy  73.64583333333333 %
#
# Epoch  92
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5700, device='cuda:0')
# train_accuracy  83.54166666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  93
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4136, device='cuda:0')
# train_accuracy  83.02083333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  94
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6797, device='cuda:0')
# train_accuracy  83.125 %
# test_accuracy  73.4375 %
#
# Epoch  95
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5431, device='cuda:0')
# train_accuracy  83.54166666666667 %
# test_accuracy  72.60416666666667 %
#
# Epoch  96
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6387, device='cuda:0')
# train_accuracy  82.5 %
# test_accuracy  74.375 %
#
# Epoch  97
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.5072, device='cuda:0')
# train_accuracy  82.70833333333333 %
# test_accuracy  73.75 %
#
# Epoch  98
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4055, device='cuda:0')
# train_accuracy  83.75 %
# test_accuracy  73.22916666666667 %
#
# Epoch  99
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6998, device='cuda:0')
# train_accuracy  81.97916666666667 %
# test_accuracy  73.75 %
#
# Epoch  100
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.6027, device='cuda:0')
# train_accuracy  83.4375 %
# test_accuracy  72.91666666666666 %
#
# Epoch  101
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4610, device='cuda:0')
# train_accuracy  83.64583333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  102
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3039, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  103
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4678, device='cuda:0')
# train_accuracy  82.70833333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  104
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4419, device='cuda:0')
# train_accuracy  85.10416666666667 %
# test_accuracy  73.64583333333333 %
#
# Epoch  105
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4525, device='cuda:0')
# train_accuracy  83.75 %
# test_accuracy  73.75 %
#
# Epoch  106
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4158, device='cuda:0')
# train_accuracy  83.75 %
# test_accuracy  72.29166666666667 %
#
# Epoch  107
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2072, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  75.0 %
#
# Epoch  108
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4716, device='cuda:0')
# train_accuracy  84.58333333333333 %
# test_accuracy  74.375 %
#
# Epoch  109
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4936, device='cuda:0')
# train_accuracy  83.33333333333334 %
# test_accuracy  72.70833333333333 %
#
# Epoch  110
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2122, device='cuda:0')
# train_accuracy  84.89583333333334 %
# test_accuracy  74.79166666666667 %
#
# Epoch  111
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1609, device='cuda:0')
# train_accuracy  86.14583333333333 %
# test_accuracy  74.375 %
#
# Epoch  112
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3176, device='cuda:0')
# train_accuracy  83.95833333333333 %
# test_accuracy  73.125 %
#
# Epoch  113
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2108, device='cuda:0')
# train_accuracy  84.79166666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  114
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2636, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  73.4375 %
#
# Epoch  115
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.4119, device='cuda:0')
# train_accuracy  83.95833333333333 %
# test_accuracy  73.125 %
#
# Epoch  116
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3316, device='cuda:0')
# train_accuracy  84.27083333333333 %
# test_accuracy  73.22916666666667 %
#
# Epoch  117
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2124, device='cuda:0')
# train_accuracy  85.10416666666667 %
# test_accuracy  73.95833333333334 %
#
# Epoch  118
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0169, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  119
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0714, device='cuda:0')
# train_accuracy  85.3125 %
# test_accuracy  73.125 %
#
# Epoch  120
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1108, device='cuda:0')
# train_accuracy  85.3125 %
# test_accuracy  73.64583333333333 %
#
# Epoch  121
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1318, device='cuda:0')
# train_accuracy  84.47916666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  122
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2356, device='cuda:0')
# train_accuracy  84.0625 %
# test_accuracy  72.91666666666666 %
#
# Epoch  123
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1522, device='cuda:0')
# train_accuracy  85.10416666666667 %
# test_accuracy  73.75 %
#
# Epoch  124
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.2749, device='cuda:0')
# train_accuracy  84.375 %
# test_accuracy  73.125 %
#
# Epoch  125
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1878, device='cuda:0')
# train_accuracy  83.75 %
# test_accuracy  73.125 %
#
# Epoch  126
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3387, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  73.85416666666667 %
#
# Epoch  127
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.3136, device='cuda:0')
# train_accuracy  83.95833333333333 %
# test_accuracy  73.22916666666667 %
#
# Epoch  128
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9433, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  129
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0503, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  74.375 %
#
# Epoch  130
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1895, device='cuda:0')
# train_accuracy  84.375 %
# test_accuracy  72.70833333333333 %
#
# Epoch  131
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9889, device='cuda:0')
# train_accuracy  85.72916666666667 %
# test_accuracy  74.89583333333333 %
#
# Epoch  132
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0906, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  74.27083333333333 %
#
# Epoch  133
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9543, device='cuda:0')
# train_accuracy  85.83333333333333 %
# test_accuracy  72.5 %
#
# Epoch  134
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8417, device='cuda:0')
# train_accuracy  86.35416666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  135
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0724, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  74.6875 %
#
# Epoch  136
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1454, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  74.47916666666666 %
#
# Epoch  137
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1622, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  73.64583333333333 %
#
# Epoch  138
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8660, device='cuda:0')
# train_accuracy  86.5625 %
# test_accuracy  72.39583333333334 %
#
# Epoch  139
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1422, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  74.27083333333333 %
#
# Epoch  140
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0682, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  71.875 %
#
# Epoch  141
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0271, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  72.29166666666667 %
#
# Epoch  142
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8885, device='cuda:0')
# train_accuracy  85.9375 %
# test_accuracy  71.875 %
#
# Epoch  143
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9750, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  74.47916666666666 %
#
# Epoch  144
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0043, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  71.66666666666667 %
#
# Epoch  145
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8607, device='cuda:0')
# train_accuracy  85.3125 %
# test_accuracy  73.22916666666667 %
#
# Epoch  146
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8388, device='cuda:0')
# train_accuracy  86.45833333333334 %
# test_accuracy  73.85416666666667 %
#
# Epoch  147
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7580, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  75.3125 %
#
# Epoch  148
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7274, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  73.33333333333333 %
#
# Epoch  149
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7591, device='cuda:0')
# train_accuracy  85.0 %
# test_accuracy  74.27083333333333 %
#
# Epoch  150
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9832, device='cuda:0')
# train_accuracy  84.16666666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  151
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8323, device='cuda:0')
# train_accuracy  86.04166666666667 %
# test_accuracy  74.58333333333333 %
#
# Epoch  152
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0269, device='cuda:0')
# train_accuracy  84.89583333333334 %
# test_accuracy  71.5625 %
#
# Epoch  153
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0047, device='cuda:0')
# train_accuracy  85.10416666666667 %
# test_accuracy  71.04166666666667 %
#
# Epoch  154
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8883, device='cuda:0')
# train_accuracy  86.04166666666667 %
# test_accuracy  73.95833333333334 %
#
# Epoch  155
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9482, device='cuda:0')
# train_accuracy  86.35416666666667 %
# test_accuracy  72.39583333333334 %
#
# Epoch  156
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.1622, device='cuda:0')
# train_accuracy  84.58333333333333 %
# test_accuracy  72.91666666666666 %
#
# Epoch  157
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9124, device='cuda:0')
# train_accuracy  85.41666666666666 %
# test_accuracy  73.95833333333334 %
#
# Epoch  158
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8553, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  74.0625 %
#
# Epoch  159
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7279, device='cuda:0')
# train_accuracy  85.52083333333333 %
# test_accuracy  71.77083333333333 %
#
# Epoch  160
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9616, device='cuda:0')
# train_accuracy  86.5625 %
# test_accuracy  73.22916666666667 %
#
# Epoch  161
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8883, device='cuda:0')
# train_accuracy  86.45833333333334 %
# test_accuracy  73.02083333333333 %
#
# Epoch  162
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7207, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  73.4375 %
#
# Epoch  163
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6675, device='cuda:0')
# train_accuracy  87.5 %
# test_accuracy  72.70833333333333 %
#
# Epoch  164
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5228, device='cuda:0')
# train_accuracy  86.45833333333334 %
# test_accuracy  73.33333333333333 %
#
# Epoch  165
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9312, device='cuda:0')
# train_accuracy  85.20833333333333 %
# test_accuracy  72.5 %
#
# Epoch  166
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7741, device='cuda:0')
# train_accuracy  85.72916666666667 %
# test_accuracy  73.64583333333333 %
#
# Epoch  167
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7904, device='cuda:0')
# train_accuracy  86.25 %
# test_accuracy  71.97916666666667 %
#
# Epoch  168
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6741, device='cuda:0')
# train_accuracy  87.5 %
# test_accuracy  71.97916666666667 %
#
# Epoch  169
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7760, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  71.875 %
#
# Epoch  170
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6613, device='cuda:0')
# train_accuracy  86.77083333333333 %
# test_accuracy  73.02083333333333 %
#
# Epoch  171
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7708, device='cuda:0')
# train_accuracy  85.625 %
# test_accuracy  72.29166666666667 %
#
# Epoch  172
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6817, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  73.22916666666667 %
#
# Epoch  173
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8032, device='cuda:0')
# train_accuracy  86.45833333333334 %
# test_accuracy  71.66666666666667 %
#
# Epoch  174
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5507, device='cuda:0')
# train_accuracy  86.97916666666666 %
# test_accuracy  72.70833333333333 %
#
# Epoch  175
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7948, device='cuda:0')
# train_accuracy  85.41666666666666 %
# test_accuracy  72.29166666666667 %
#
# Epoch  176
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6477, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  73.54166666666667 %
#
# Epoch  177
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3416, device='cuda:0')
# train_accuracy  86.25 %
# test_accuracy  71.04166666666667 %
#
# Epoch  178
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8203, device='cuda:0')
# train_accuracy  86.875 %
# test_accuracy  72.5 %
#
# Epoch  179
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8898, device='cuda:0')
# train_accuracy  86.04166666666667 %
# test_accuracy  73.75 %
#
# Epoch  180
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.9031, device='cuda:0')
# train_accuracy  85.9375 %
# test_accuracy  73.4375 %
#
# Epoch  181
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7785, device='cuda:0')
# train_accuracy  86.77083333333333 %
# test_accuracy  72.91666666666666 %
#
# Epoch  182
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8213, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  73.75 %
#
# Epoch  183
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(5.0425, device='cuda:0')
# train_accuracy  86.04166666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  184
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6428, device='cuda:0')
# train_accuracy  87.5 %
# test_accuracy  73.02083333333333 %
#
# Epoch  185
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.7004, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  73.125 %
#
# Epoch  186
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.8689, device='cuda:0')
# train_accuracy  86.04166666666667 %
# test_accuracy  72.70833333333333 %
#
# Epoch  187
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4934, device='cuda:0')
# train_accuracy  86.25 %
# test_accuracy  72.8125 %
#
# Epoch  188
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5842, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  72.60416666666667 %
#
# Epoch  189
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6701, device='cuda:0')
# train_accuracy  86.97916666666666 %
# test_accuracy  70.9375 %
#
# Epoch  190
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4947, device='cuda:0')
# train_accuracy  87.70833333333333 %
# test_accuracy  71.97916666666667 %
#
# Epoch  191
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6385, device='cuda:0')
# train_accuracy  86.25 %
# test_accuracy  70.9375 %
#
# Epoch  192
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6207, device='cuda:0')
# train_accuracy  86.25 %
# test_accuracy  72.08333333333333 %
#
# Epoch  193
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.6582, device='cuda:0')
# train_accuracy  87.08333333333333 %
# test_accuracy  72.8125 %
#
# Epoch  194
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4158, device='cuda:0')
# train_accuracy  88.33333333333333 %
# test_accuracy  72.60416666666667 %
#
# Epoch  195
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4587, device='cuda:0')
# train_accuracy  87.39583333333333 %
# test_accuracy  72.70833333333333 %
#
# Epoch  196
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3176, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  71.35416666666666 %
#
# Epoch  197
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3249, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  71.77083333333333 %
#
# Epoch  198
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2405, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  72.1875 %
#
# Epoch  199
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0938, device='cuda:0')
# train_accuracy  88.95833333333333 %
# test_accuracy  72.1875 %
#
# Epoch  200
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1735, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  72.5 %
#
# Epoch  201
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3492, device='cuda:0')
# train_accuracy  87.5 %
# test_accuracy  71.66666666666667 %
#
# Epoch  202
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1469, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  72.60416666666667 %
#
# Epoch  203
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2734, device='cuda:0')
# train_accuracy  87.8125 %
# test_accuracy  73.54166666666667 %
#
# Epoch  204
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1174, device='cuda:0')
# train_accuracy  88.02083333333334 %
# test_accuracy  71.875 %
#
# Epoch  205
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.5375, device='cuda:0')
# train_accuracy  86.97916666666666 %
# test_accuracy  73.22916666666667 %
#
# Epoch  206
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2487, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  73.125 %
#
# Epoch  207
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3915, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  73.4375 %
#
# Epoch  208
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3438, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  71.77083333333333 %
#
# Epoch  209
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4309, device='cuda:0')
# train_accuracy  88.54166666666666 %
# test_accuracy  72.08333333333333 %
#
# Epoch  210
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1433, device='cuda:0')
# train_accuracy  88.22916666666667 %
# test_accuracy  71.875 %
#
# Epoch  211
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3233, device='cuda:0')
# train_accuracy  88.54166666666666 %
# test_accuracy  72.60416666666667 %
#
# Epoch  212
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2598, device='cuda:0')
# train_accuracy  88.33333333333333 %
# test_accuracy  72.5 %
#
# Epoch  213
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1631, device='cuda:0')
# train_accuracy  89.0625 %
# test_accuracy  71.77083333333333 %
#
# Epoch  214
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1171, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  71.77083333333333 %
#
# Epoch  215
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3195, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  75.10416666666667 %
#
# Epoch  216
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9062, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  72.1875 %
#
# Epoch  217
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1037, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  71.77083333333333 %
#
# Epoch  218
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0638, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  219
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2476, device='cuda:0')
# train_accuracy  88.95833333333333 %
# test_accuracy  71.5625 %
#
# Epoch  220
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9288, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  71.66666666666667 %
#
# Epoch  221
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2158, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  71.45833333333333 %
#
# Epoch  222
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3654, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  72.08333333333333 %
#
# Epoch  223
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2817, device='cuda:0')
# train_accuracy  86.875 %
# test_accuracy  72.70833333333333 %
#
# Epoch  224
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3510, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  71.97916666666667 %
#
# Epoch  225
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1887, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  73.02083333333333 %
#
# Epoch  226
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1894, device='cuda:0')
# train_accuracy  88.64583333333333 %
# test_accuracy  71.77083333333333 %
#
# Epoch  227
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1769, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  72.60416666666667 %
#
# Epoch  228
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0467, device='cuda:0')
# train_accuracy  87.8125 %
# test_accuracy  71.875 %
#
# Epoch  229
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0776, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  72.29166666666667 %
#
# Epoch  230
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.4789, device='cuda:0')
# train_accuracy  87.29166666666667 %
# test_accuracy  71.14583333333333 %
#
# Epoch  231
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8602, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  72.5 %
#
# Epoch  232
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3694, device='cuda:0')
# train_accuracy  87.1875 %
# test_accuracy  72.39583333333334 %
#
# Epoch  233
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1125, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  72.1875 %
#
# Epoch  234
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9202, device='cuda:0')
# train_accuracy  88.125 %
# test_accuracy  72.08333333333333 %
#
# Epoch  235
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3429, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  70.83333333333334 %
#
# Epoch  236
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2357, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  71.35416666666666 %
#
# Epoch  237
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2551, device='cuda:0')
# train_accuracy  88.33333333333333 %
# test_accuracy  70.83333333333334 %
#
# Epoch  238
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8803, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  72.1875 %
#
# Epoch  239
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3369, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  240
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9179, device='cuda:0')
# train_accuracy  88.75 %
# test_accuracy  72.1875 %
#
# Epoch  241
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9627, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  71.25 %
#
# Epoch  242
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2011, device='cuda:0')
# train_accuracy  88.02083333333334 %
# test_accuracy  72.29166666666667 %
#
# Epoch  243
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7983, device='cuda:0')
# train_accuracy  89.6875 %
# test_accuracy  72.60416666666667 %
#
# Epoch  244
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9234, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  71.45833333333333 %
#
# Epoch  245
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2590, device='cuda:0')
# train_accuracy  88.33333333333333 %
# test_accuracy  73.33333333333333 %
#
# Epoch  246
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7597, device='cuda:0')
# train_accuracy  90.0 %
# test_accuracy  70.3125 %
#
# Epoch  247
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0231, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  72.5 %
#
# Epoch  248
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9726, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  70.83333333333334 %
#
# Epoch  249
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9228, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  70.83333333333334 %
#
# Epoch  250
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9965, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  71.5625 %
#
# Epoch  251
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9709, device='cuda:0')
# train_accuracy  88.64583333333333 %
# test_accuracy  71.14583333333333 %
#
# Epoch  252
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0907, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  71.04166666666667 %
#
# Epoch  253
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9384, device='cuda:0')
# train_accuracy  89.79166666666667 %
# test_accuracy  72.1875 %
#
# Epoch  254
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0929, device='cuda:0')
# train_accuracy  87.8125 %
# test_accuracy  71.25 %
#
# Epoch  255
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7866, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  72.8125 %
#
# Epoch  256
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.0741, device='cuda:0')
# train_accuracy  88.02083333333334 %
# test_accuracy  71.66666666666667 %
#
# Epoch  257
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.2672, device='cuda:0')
# train_accuracy  87.60416666666667 %
# test_accuracy  71.5625 %
#
# Epoch  258
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1261, device='cuda:0')
# train_accuracy  87.70833333333333 %
# test_accuracy  72.29166666666667 %
#
# Epoch  259
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9787, device='cuda:0')
# train_accuracy  89.375 %
# test_accuracy  71.5625 %
#
# Epoch  260
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1429, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  72.08333333333333 %
#
# Epoch  261
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8096, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  71.04166666666667 %
#
# Epoch  262
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6449, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  70.52083333333333 %
#
# Epoch  263
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7841, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  71.77083333333333 %
#
# Epoch  264
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7254, device='cuda:0')
# train_accuracy  90.9375 %
# test_accuracy  71.04166666666667 %
#
# Epoch  265
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7384, device='cuda:0')
# train_accuracy  89.79166666666667 %
# test_accuracy  71.97916666666667 %
#
# Epoch  266
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9334, device='cuda:0')
# train_accuracy  89.375 %
# test_accuracy  72.39583333333334 %
#
# Epoch  267
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8473, device='cuda:0')
# train_accuracy  90.10416666666666 %
# test_accuracy  70.20833333333333 %
#
# Epoch  268
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.1540, device='cuda:0')
# train_accuracy  87.91666666666667 %
# test_accuracy  71.66666666666667 %
#
# Epoch  269
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6925, device='cuda:0')
# train_accuracy  88.85416666666667 %
# test_accuracy  71.25 %
#
# Epoch  270
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7593, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  72.5 %
#
# Epoch  271
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7186, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  72.39583333333334 %
#
# Epoch  272
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8209, device='cuda:0')
# train_accuracy  90.3125 %
# test_accuracy  72.91666666666666 %
#
# Epoch  273
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7636, device='cuda:0')
# train_accuracy  88.75 %
# test_accuracy  69.58333333333333 %
#
# Epoch  274
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9439, device='cuda:0')
# train_accuracy  89.27083333333333 %
# test_accuracy  72.8125 %
#
# Epoch  275
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5650, device='cuda:0')
# train_accuracy  90.20833333333333 %
# test_accuracy  72.5 %
#
# Epoch  276
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.9724, device='cuda:0')
# train_accuracy  88.4375 %
# test_accuracy  72.91666666666666 %
#
# Epoch  277
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8885, device='cuda:0')
# train_accuracy  88.75 %
# test_accuracy  71.14583333333333 %
#
# Epoch  278
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6690, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  72.91666666666666 %
#
# Epoch  279
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6929, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  72.1875 %
#
# Epoch  280
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6948, device='cuda:0')
# train_accuracy  88.22916666666667 %
# test_accuracy  70.83333333333334 %
#
# Epoch  281
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(4.3422, device='cuda:0')
# train_accuracy  87.8125 %
# test_accuracy  71.5625 %
#
# Epoch  282
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.8065, device='cuda:0')
# train_accuracy  90.10416666666666 %
# test_accuracy  71.77083333333333 %
#
# Epoch  283
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7998, device='cuda:0')
# train_accuracy  89.16666666666667 %
# test_accuracy  69.89583333333333 %
#
# Epoch  284
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5198, device='cuda:0')
# train_accuracy  90.20833333333333 %
# test_accuracy  70.41666666666667 %
#
# Epoch  285
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7180, device='cuda:0')
# train_accuracy  89.47916666666667 %
# test_accuracy  70.41666666666667 %
#
# Epoch  286
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5191, device='cuda:0')
# train_accuracy  90.20833333333333 %
# test_accuracy  71.25 %
#
# Epoch  287
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7712, device='cuda:0')
# train_accuracy  90.20833333333333 %
# test_accuracy  71.04166666666667 %
#
# Epoch  288
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5638, device='cuda:0')
# train_accuracy  90.10416666666666 %
# test_accuracy  72.39583333333334 %
#
# Epoch  289
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6855, device='cuda:0')
# train_accuracy  89.47916666666667 %
# test_accuracy  71.04166666666667 %
#
# Epoch  290
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6142, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  72.08333333333333 %
#
# Epoch  291
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5766, device='cuda:0')
# train_accuracy  89.58333333333334 %
# test_accuracy  71.66666666666667 %
#
# Epoch  292
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5474, device='cuda:0')
# train_accuracy  90.41666666666667 %
# test_accuracy  70.41666666666667 %
#
# Epoch  293
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.7398, device='cuda:0')
# train_accuracy  90.0 %
# test_accuracy  70.9375 %
#
# Epoch  294
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5607, device='cuda:0')
# train_accuracy  89.89583333333333 %
# test_accuracy  72.29166666666667 %
#
# Epoch  295
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.4790, device='cuda:0')
# train_accuracy  91.04166666666667 %
# test_accuracy  71.14583333333333 %
#
# Epoch  296
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5055, device='cuda:0')
# train_accuracy  90.72916666666667 %
# test_accuracy  70.9375 %
#
# Epoch  297
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.5523, device='cuda:0')
# train_accuracy  90.52083333333333 %
# test_accuracy  71.35416666666666 %
#
# Epoch  298
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.3401, device='cuda:0')
# train_accuracy  90.9375 %
# test_accuracy  71.04166666666667 %
#
# Epoch  299
# ['acc', 'auc', 'fmeasure']
# Training Loss  tensor(3.6508, device='cuda:0')
# train_accuracy  89.47916666666667 %
# test_accuracy  71.45833333333333 %
